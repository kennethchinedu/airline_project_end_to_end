# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
from datetime import datetime

# Load environment variables from .env file
load_dotenv()

start_year = '2024'
end_year = '2024'
order_by = 'date'
api_key_env_variable = 'NETFLIX_API_KEY'  # New environment variable for API key
limit = 100  # Example: Set the limit for each request

def extract_titles():
    all_data = []
    offset = 0

    # Continue fetching data until there are no more results left
    while True:
        url = f"https://api.apilayer.com/unogs/search/titles?start_year={start_year}&order_by={order_by}&end_year={end_year}&limit={limit}&offset={offset}"
        payload = {}
        headers = {"apikey": os.getenv(api_key_env_variable)}

        response = requests.request("GET", url, headers=headers, data=payload)
        data = response.json()

        # Check if there are no more results left
        if not data["results"]:
            break

        # Extract relevant fields from each result and append to all_data
        for result in data["results"]:
            all_data.append({
                "imdb_id": result["imdb_id"],
                "title": result["title"],
                "rating": result["rating"],
                "year": result["year"],
                "runtime": result["runtime"],
                "top250": result["top250"],
                "top250tv": result["top250tv"],
                "title_date": result["title_date"]
            })

        # Increment the offset for the next request
        offset += limit

    # Create a DataFrame from all_data
    df = pd.DataFrame(all_data)

    # Save the DataFrame as a new CSV file with timestamp
    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
    csv_file_name = f'Netflix2024_{timestamp}.csv'
    df.to_csv(csv_file_name, index=False)
    print(f"CSV file {csv_file_name} saved successfully.")

    # Display the DataFrame
    return df

# extract_titles()

# %%
extract_titles()
# Out:
# CSV file Netflix2024_20240307235501.csv saved successfully.
#         imdb_id                                         title rating  year  \
# 0                                Pokémon Horizons: The Series         2024
# 1     tt2910814                                    The Signal      6  2024
# 2     tt8367814                                 The Gentlemen    7.8  2024
# 3                ARA San Juan: The Submarine that Disappeared         2024
# 4    tt28867594                                  Kultus Iblis      0  2024
# ..          ...                                           ...    ...   ...
# 134                   You Are What You Eat: A Twin Experiment         2024
# 135   tt0978808                                  Fool Me Once    7.3  2024
# 136                                                 Bitconned         2024
# 137  tt21742340                                The Influencer    5.5  2024
# 138  tt27790130            The Big Nailed It Baking Challenge      0  2024
#
#     runtime  top250  top250tv  title_date
# 0         0       0         0  2024-03-07
# 1         0       0         0  2024-03-07
# 2         0       0         0  2024-03-07
# 3         0       0         0  2024-03-07
# 4      5903       0         0  2024-03-07
# ..      ...     ...       ...         ...
# 134       0       0         0  2024-01-01
# 135       0       0         0  2024-01-01
# 136    5647       0         0  2024-01-01
# 137       0       0         0  2023-12-13
# 138       0       0         0  2023-08-04
#
# [139 rows x 8 columns]

# %%
def extract_people():
    all_data = []
    offset = 500

    # Continue fetching data until there are no more results left
    while True:
        url = f"https://api.apilayer.com/unogs/search/people?person_type=Director"
        payload = {}
        headers = {"apikey": os.getenv(api_key_env_variable)}

        response = requests.request("GET", url, headers=headers, data=payload)
        data = response.json()

        # Check if there are no more results left
        if not data["results"]:
            break

        # Extract relevant fields from each result and append to all_data
        for result in data["results"]:
            all_data.append({
                "netflix_id": result["netflix_id"],
                "full_name": result["full_name"],
                "person_type": result["person_type"],
                "title": result["title"]
            })
        
        # Increment the offset for the next request
        offset += limit
        print(f'loaded{offset} data')

    # Create a DataFrame from all_data
    df = pd.DataFrame(all_data)

    # Save the DataFrame as a new CSV file with timestamp
    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
    csv_file_name = f'Netflix_people_{timestamp}.csv'
    df.to_csv(csv_file_name, index=False)
    print(f"CSV file {csv_file_name} saved successfully.")

    # Display the DataFrame
    return df

# %%
extract_people()
# Out:
# loaded600 data
# loaded700 data
# loaded800 data
# loaded900 data
# <frozen genericpath>:89: RuntimeWarning: coroutine 'extract_people' was never awaited
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 extract_people()
#
# Cell In[77], line 11, in extract_people()
#       8 payload = {}
#       9 headers = {"apikey": os.getenv(api_key_env_variable)}
# ---> 11 response = requests.request("GET", url, headers=headers, data=payload)
#      12 data = response.json()
#      14 # Check if there are no more results left
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 # Trigger any extra validation we need to do.
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     407     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1056 # Force connect early to allow us to validate the connection.
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#    1061     warnings.warn(
#    1062         (
#    1063             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1068         InsecureRequestWarning,
#    1069     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039             if timeout == 0.0:
#    1040                 # non-blocking
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#    1044     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1318     if timeout == 0.0 and block:
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#    1322     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import requests

person_type='Actor'

url = f"https://api.apilayer.com/unogs/search/people?person_type=Director"

payload = { }

headers= {
    "apikey": "LQpuQgeu4U6qvBAKZd4TcJeDHGDh4RFf"
}

response = requests.get(url, headers=headers, params=payload)

status_code = response.status_code
result = response.text

print(status_code)
print(result)
# Out:
# 200
# {
#     "Object": {
#         "total": 515128,
#         "limit": 100,
#         "offset": 0
#     },
#     "results": [
#         {
#             "netflix_id": 70305209,
#             "full_name": " Alfred Molina",
#             "person_type": "Actor",
#             "title": "We&#39;ll Never Have Paris"
#         },
#         {
#             "netflix_id": 70306661,
#             "full_name": " Amanda Fuller",
#             "person_type": "Actor",
#             "title": "Starry Eyes"
#         },
#         {
#             "netflix_id": 70307594,
#             "full_name": " Corey Eid",
#             "person_type": "Actor",
#             "title": "Alien Abduction"
#         },
#         {
#             "netflix_id": 80007406,
#             "full_name": " Dan Stevens",
#             "person_type": "Actor",
#             "title": "A Walk Among the Tombstones"
#         },
#         {
#             "netflix_id": 70307652,
#             "full_name": " David Henrie",
#             "person_type": "Actor",
#             "title": "Little Boy"
#         },
#         {
#             "netflix_id": 70259897,
#             "full_name": " Diane Lane",
#             "person_type": "Actor",
#             "title": "Half the Sky: Turning Oppression into Opportunity for Women Worldwide"
#         },
#         {
#             "netflix_id": 80007260,
#             "full_name": " Dylan Postl",
#             "person_type": "Actor",
#             "title": "Leprechaun: Origins"
#         },
#         {
#             "netflix_id": 70256174,
#             "full_name": " Erik Nelson",
#             "person_type": "Director",
#             "title": "Dinotasia"
#         },
#         {
#             "netflix_id": 70259570,
#             "full_name": " Jose Miguel Carmona",
#             "person_type": "Actor",
#             "title": "Flamenco, Flamenco"
#         },
#         {
#             "netflix_id": 70307652,
#             "full_name": " Kevin James",
#             "person_type": "Actor",
#             "title": "Little Boy"
#         },
#         {
#             "netflix_id": 70306294,
#             "full_name": " Krista Kosonen",
#             "person_type": "Actor",
#             "title": "Big Significant Things"
#         },
#         {
#             "netflix_id": 81136842,
#             "full_name": " Shiori Yoshida",
#             "person_type": "Actor",
#             "title": "Chiwawa"
#         },
#         {
#             "netflix_id": 80007260,
#             "full_name": " Stephanie Bennett",
#             "person_type": "Actor",
#             "title": "Leprechaun: Origins"
#         },
#         {
#             "netflix_id": 70306294,
#             "full_name": " Sylvia Grace Crim",
#             "person_type": "Actor",
#             "title": "Big Significant Things"
#         },
#         {
#             "netflix_id": 60025171,
#             "full_name": "\"Lee\" Georges Quinones",
#             "person_type": "Actor",
#             "title": "Wild Style"
#         },
#         {
#             "netflix_id": 81081603,
#             "full_name": "\"Riley\" Lakdhar Dridi",
#             "person_type": "Actor",
#             "title": "An Easy Girl"
#         },
#         {
#             "netflix_id": 81274984,
#             "full_name": "&#39;Najite Dede",
#             "person_type": "Actor",
#             "title": "Ojos in d&#39; House"
#         },
#         {
#             "netflix_id": 81270775,
#             "full_name": "&#39;Najite Dede",
#             "person_type": "Actor",
#             "title": "It&#39;s Her Day"
#         },
#         {
#             "netflix_id": 81409152,
#             "full_name": ", Daniel Edelstyn",
#             "person_type": "Director",
#             "title": "How To Re-Establish A Vodka Empire"
#         },
#         {
#             "netflix_id": 70076246,
#             "full_name": "000 Feet&#39;)",
#             "person_type": "Creator",
#             "title": "Twilight Zone: The Movie"
#         },
#         {
#             "netflix_id": 81053303,
#             "full_name": "070 Shake",
#             "person_type": "Actor",
#             "title": "Entergalactic"
#         },
#         {
#             "netflix_id": 70273709,
#             "full_name": "1875-1945&#39;)",
#             "person_type": "Creator",
#             "title": "Teenage"
#         },
#         {
#             "netflix_id": 81679532,
#             "full_name": "1G",
#             "person_type": "Actor",
#             "title": "Blue Marble World Tour"
#         },
#         {
#             "netflix_id": 80162057,
#             "full_name": "1kg Sugar",
#             "person_type": "Creator",
#             "title": "Sheep and Wolves"
#         },
#         {
#             "netflix_id": 80145087,
#             "full_name": "2 Chainz",
#             "person_type": "Actor",
#             "title": "Rapture"
#         },
#         {
#             "netflix_id": 80151952,
#             "full_name": "2Mex",
#             "person_type": "Actor",
#             "title": "This Is the Life"
#         },
#         {
#             "netflix_id": 70155752,
#             "full_name": "302 by)",
#             "person_type": "Creator",
#             "title": "Compulsion"
#         },
#         {
#             "netflix_id": 80161826,
#             "full_name": "4Minute",
#             "person_type": "Actor",
#             "title": "2015 Dream Concert"
#         },
#         {
#             "netflix_id": 81408961,
#             "full_name": "5 Seconds of Summer",
#             "person_type": "Actor",
#             "title": "5 Seconds Of Summer: So Perfect"
#         },
#         {
#             "netflix_id": 70122297,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Caught in the Crossfire"
#         },
#         {
#             "netflix_id": 70261119,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "How to Make Money Selling Drugs"
#         },
#         {
#             "netflix_id": 70245670,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Fire with Fire"
#         },
#         {
#             "netflix_id": 80038447,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Southpaw"
#         },
#         {
#             "netflix_id": 70223593,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "All Things Fall Apart"
#         },
#         {
#             "netflix_id": 70223593,
#             "full_name": "50 Cent",
#             "person_type": "Creator",
#             "title": "All Things Fall Apart"
#         },
#         {
#             "netflix_id": 80196448,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Den of Thieves"
#         },
#         {
#             "netflix_id": 70244551,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Freelancers"
#         },
#         {
#             "netflix_id": 70253159,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Frozen Ground"
#         },
#         {
#             "netflix_id": 70053825,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Home of the Brave"
#         },
#         {
#             "netflix_id": 80206908,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Escape Plan 2: Hades"
#         },
#         {
#             "netflix_id": 70170575,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Blood Out"
#         },
#         {
#             "netflix_id": 70098605,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Righteous Kill"
#         },
#         {
#             "netflix_id": 70199239,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Set Up"
#         },
#         {
#             "netflix_id": 70115877,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Dead Man Running"
#         },
#         {
#             "netflix_id": 80013712,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "The Prince"
#         },
#         {
#             "netflix_id": 70124558,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Twelve"
#         },
#         {
#             "netflix_id": 70273614,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Escape Plan"
#         },
#         {
#             "netflix_id": 70117540,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "13"
#         },
#         {
#             "netflix_id": 81123458,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Escape Plan: The Extractors"
#         },
#         {
#             "netflix_id": 70298433,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Power"
#         },
#         {
#             "netflix_id": 70117901,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Streets of Blood"
#         },
#         {
#             "netflix_id": 70039177,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Get Rich or Die Tryin&#39;"
#         },
#         {
#             "netflix_id": 70154739,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Gun"
#         },
#         {
#             "netflix_id": 80010636,
#             "full_name": "50 Cent",
#             "person_type": "Actor",
#             "title": "Dream School"
#         },
#         {
#             "netflix_id": 70128532,
#             "full_name": "9 Million Sam",
#             "person_type": "Actor",
#             "title": "Fireball"
#         },
#         {
#             "netflix_id": 81440771,
#             "full_name": "9m88",
#             "person_type": "Actor",
#             "title": "I missed you: Director&#39;s Cut"
#         },
#         {
#             "netflix_id": 80145087,
#             "full_name": "A Boogie Wit Da Hoodie",
#             "person_type": "Actor",
#             "title": "Rapture"
#         },
#         {
#             "netflix_id": 80145087,
#             "full_name": "A Boogie Wit tha Hoodie",
#             "person_type": "Actor",
#             "title": "Rapture"
#         },
#         {
#             "netflix_id": 81430301,
#             "full_name": "A Gyeong",
#             "person_type": "Creator",
#             "title": "Mad for Each Other"
#         },
#         {
#             "netflix_id": 81687520,
#             "full_name": "A Gyeong",
#             "person_type": "Creator",
#             "title": "True to Love"
#         },
#         {
#             "netflix_id": 80068027,
#             "full_name": "A Martinez",
#             "person_type": "Actor",
#             "title": "Cruel Justice"
#         },
#         {
#             "netflix_id": 70227646,
#             "full_name": "A Martinez",
#             "person_type": "Actor",
#             "title": "California Solo"
#         },
#         {
#             "netflix_id": 70178600,
#             "full_name": "A Martinez",
#             "person_type": "Actor",
#             "title": "Mega Python vs. Gatoroid"
#         },
#         {
#             "netflix_id": 70291092,
#             "full_name": "A Martinez",
#             "person_type": "Actor",
#             "title": "Curse of Chucky"
#         },
#         {
#             "netflix_id": 70244441,
#             "full_name": "a short film written by)",
#             "person_type": "Creator",
#             "title": "Why Stop Now"
#         },
#         {
#             "netflix_id": 70166139,
#             "full_name": "A Tribe Called Quest",
#             "person_type": "Actor",
#             "title": "Beats, Rhymes and Life: The Travels of A Tribe Called Quest"
#         },
#         {
#             "netflix_id": 80037759,
#             "full_name": "A$AP Rocky",
#             "person_type": "Actor",
#             "title": "Dope"
#         },
#         {
#             "netflix_id": 81604831,
#             "full_name": "A&#39;Noelle Jackson",
#             "person_type": "Actor",
#             "title": "LOL Surprise! Winter Fashion Show"
#         },
#         {
#             "netflix_id": 80179173,
#             "full_name": "A-chan",
#             "person_type": "Actor",
#             "title": "Pens\u00e9es"
#         },
#         {
#             "netflix_id": 81645371,
#             "full_name": "A-chan",
#             "person_type": "Actor",
#             "title": "Love Like a K-Drama"
#         },
#         {
#             "netflix_id": 80139543,
#             "full_name": "A-ga Shin",
#             "person_type": "Director",
#             "title": "If You Were Me 6"
#         },
#         {
#             "netflix_id": 81504875,
#             "full_name": "a-ha",
#             "person_type": "Actor",
#             "title": "a-ha: The Movie"
#         },
#         {
#             "netflix_id": 81613603,
#             "full_name": "A-Preaw",
#             "person_type": "Actor",
#             "title": "Cat Radio TV"
#         },
#         {
#             "netflix_id": 80214013,
#             "full_name": "A-ra Go",
#             "person_type": "Actor",
#             "title": "Black"
#         },
#         {
#             "netflix_id": 81577427,
#             "full_name": "A. Galak",
#             "person_type": "Actor",
#             "title": "Mat Kilau"
#         },
#         {
#             "netflix_id": 81281015,
#             "full_name": "A. Galak",
#             "person_type": "Actor",
#             "title": "Superstition"
#         },
#         {
#             "netflix_id": 81281019,
#             "full_name": "A. Galak Zabaire",
#             "person_type": "Actor",
#             "title": "Munafik"
#         },
#         {
#             "netflix_id": 70265487,
#             "full_name": "A. Hameed Ali A.H. Almaas",
#             "person_type": "Actor",
#             "title": "With One Voice"
#         },
#         {
#             "netflix_id": 80029568,
#             "full_name": "A. J. McLean",
#             "person_type": "Actor",
#             "title": "Backstreet Boys: Show &#39;Em What You&#39;re Made Of"
#         },
#         {
#             "netflix_id": 80150390,
#             "full_name": "A. L. Vijay",
#             "person_type": "Director",
#             "title": "Abhinetri"
#         },
#         {
#             "netflix_id": 80150390,
#             "full_name": "A. L. Vijay",
#             "person_type": "Actor",
#             "title": "Abhinetri"
#         },
#         {
#             "netflix_id": 81155784,
#             "full_name": "A. L. Vijay",
#             "person_type": "Director",
#             "title": "Watchman"
#         },
#         {
#             "netflix_id": 81043541,
#             "full_name": "A. Murat Ozgen",
#             "person_type": "Actor",
#             "title": "Dabbe: Ci\u0307n \u00c7arpmasi"
#         },
#         {
#             "netflix_id": 70027955,
#             "full_name": "A. Norevo",
#             "person_type": "Creator",
#             "title": "Dr. Orloff&#39;s Monster"
#         },
#         {
#             "netflix_id": 81308666,
#             "full_name": "A. Panneeirchelvam",
#             "person_type": "Actor",
#             "title": "Vyjayanthi"
#         },
#         {
#             "netflix_id": 81289658,
#             "full_name": "A. Raajdheep",
#             "person_type": "Director",
#             "title": "Asura Guru"
#         },
#         {
#             "netflix_id": 81336381,
#             "full_name": "A. Rachman",
#             "person_type": "Director",
#             "title": "The Longer, The Better"
#         },
#         {
#             "netflix_id": 81425200,
#             "full_name": "A. Rahim",
#             "person_type": "Actor",
#             "title": "Bukit Kepong"
#         },
#         {
#             "netflix_id": 81425199,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "Duyung"
#         },
#         {
#             "netflix_id": 81409761,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "Raya Tak Jadi"
#         },
#         {
#             "netflix_id": 81490206,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "Nana Tanjung"
#         },
#         {
#             "netflix_id": 81490208,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "Nana Tanjung 2"
#         },
#         {
#             "netflix_id": 81425204,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "Syif Malam Raya"
#         },
#         {
#             "netflix_id": 81409759,
#             "full_name": "A. Razak Mohaideen",
#             "person_type": "Director",
#             "title": "I Know What You Did Last Raya"
#         },
#         {
#             "netflix_id": 60034557,
#             "full_name": "A. Russell Andrews",
#             "person_type": "Actor",
#             "title": "The Punisher"
#         },
#         {
#             "netflix_id": 80158389,
#             "full_name": "A. Salaam",
#             "person_type": "Director",
#             "title": "Chadi Jawani Budhe Nu"
#         },
#         {
#             "netflix_id": 80158479,
#             "full_name": "A. Salaam",
#             "person_type": "Director",
#             "title": "Salaakhen"
#         },
#         {
#             "netflix_id": 81644286,
#             "full_name": "A. Sarkunam",
#             "person_type": "Director",
#             "title": "Pattathu Arasan"
#         },
#         {
#             "netflix_id": 80097249,
#             "full_name": "A. Scott Berg",
#             "person_type": "Creator",
#             "title": "Genius"
#         },
#         {
#             "netflix_id": 70273611,
#             "full_name": "A. Scott Berg",
#             "person_type": "Actor",
#             "title": "Salinger"
#         }
#     ]
# }

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

def load_people_data(titles_df):
    api_key_env_variable = 'NETFLIX_API_KEY'  # New environment variable for API key

    # Extract IMDb IDs from the titles DataFrame
    imdb_ids = titles_df['imdb_id'].tolist()

    all_people_data = []

    # Iterate through each IMDb ID and fetch people associated with the title
    for imdb_id in imdb_ids:
        url = f"https://api.apilayer.com/unogs/search/people"
        payload = {"imdb_id": imdb_id}
        headers = {"apikey": os.getenv(api_key_env_variable)}

        response = requests.get(url, headers=headers, params=payload)
        data = response.json()

        # Append people data to the list
        all_people_data.extend(data["results"])

    # Create a DataFrame from all_people_data
    people_df = pd.DataFrame(all_people_data)

    return people_df

# Example usage:
# Load titles data
titles_df = pd.read_csv('Netflix2024_20240307235501.csv')

# Load people's data based on the titles
people_df = load_people_data(titles_df)

# Save the DataFrame as a new CSV file
timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
csv_file_name = f'Netflix_people_{timestamp}.csv'
people_df.to_csv(csv_file_name, index=False)
print(f"CSV file {csv_file_name} saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[80], line 36
#      32     return people_df
#      34 # Example usage:
#      35 # Load titles data
# ---> 36 titles_df = pd.read_csv('Netflix2024_YYYYMMDDHHMMSS.csv')
#      38 # Load people's data based on the titles
#      39 people_df = load_people_data(titles_df)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1024, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1011 kwds_defaults = _refine_defaults_read(
#    1012     dialect,
#    1013     delimiter,
#    (...)
#    1020     dtype_backend=dtype_backend,
#    1021 )
#    1022 kwds.update(kwds_defaults)
# -> 1024 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:618, in _read(filepath_or_buffer, kwds)
#     615 _validate_names(kwds.get("names", None))
#     617 # Create the parser.
# --> 618 parser = TextFileReader(filepath_or_buffer, **kwds)
#     620 if chunksize or iterator:
#     621     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1618, in TextFileReader.__init__(self, f, engine, **kwds)
#    1615     self.options["has_index_names"] = kwds["has_index_names"]
#    1617 self.handles: IOHandles | None = None
# -> 1618 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1878, in TextFileReader._make_engine(self, f, engine)
#    1876     if "b" not in mode:
#    1877         mode += "b"
# -> 1878 self.handles = get_handle(
#    1879     f,
#    1880     mode,
#    1881     encoding=self.options.get("encoding", None),
#    1882     compression=self.options.get("compression", None),
#    1883     memory_map=self.options.get("memory_map", False),
#    1884     is_text=is_text,
#    1885     errors=self.options.get("encoding_errors", "strict"),
#    1886     storage_options=self.options.get("storage_options", None),
#    1887 )
#    1888 assert self.handles is not None
#    1889 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Netflix2024_YYYYMMDDHHMMSS.csv'
