# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
from datetime import datetime

# %%
# ACCESS_KEY = os.getenv(flight_access_key)

def extract_flight():
    
    params = {
    'access_key': '0d4a1c5045c1bb5f4c5c19ef09cbf85a'}

    api_result = requests.get('http://api.aviationstack.com/v1/flights', params)

    api_response = api_result.json()

    print(api_response)


extract_flight()
# Out:
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 285203}, 'data': [{'flight_date': '2024-03-09', 'flight_status': 'landed', 'departure': {'airport': 'Hobart', 'timezone': 'Australia/Hobart', 'iata': 'HBA', 'icao': 'YMHB', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T07:00:00+00:00', 'estimated': '2024-03-09T07:00:00+00:00', 'actual': '2024-03-08T06:33:00+00:00', 'estimated_runway': '2024-03-08T06:33:00+00:00', 'actual_runway': '2024-03-08T06:33:00+00:00'}, 'arrival': {'airport': 'Launceston', 'timezone': 'Australia/Hobart', 'iata': 'LST', 'icao': 'YMLT', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:22:00+00:00', 'estimated': '2024-03-08T07:22:00+00:00', 'actual': '2024-03-08T06:54:00+00:00', 'estimated_runway': '2024-03-08T06:54:00+00:00', 'actual_runway': '2024-03-08T06:54:00+00:00'}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None
# ...

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
from datetime import datetime


# Load environment variables from .env file
load_dotenv()
today  = datetime.now().strftime('%Y-%m-%d')

api_key = os.getenv('AVIATIONSTACK_API_KEY')  # Getting API key from environment variable

def extract_flights():
    all_data = []
    limit = 500  # Set the limit for each request
    offset = 0

    while True:
        params = {'access_key': api_key, 'limit': limit, 'offset': offset }
        api_result = requests.get('http://api.aviationstack.com/v1/flights', params)
        data = api_result.json()

        # Check if the 'data' key exists in the response
        if 'data' not in data:
            print("Error: 'data' key not found in API response.")
            return None

        # Check if there are no more results left
        if not data["data"]:
            break

        for flight_data in data["data"]:
            # Extract all flight data fields
            all_data.append({
                "flight_date": flight_data["flight_date"],
                "flight_status": flight_data["flight_status"],
                "departure_airport": flight_data["departure"]["airport"],
                "departure_timezone": flight_data["departure"]["timezone"],
                "departure_iata": flight_data["departure"]["iata"],
                "departure_icao": flight_data["departure"]["icao"],
                "departure_terminal": flight_data["departure"]["terminal"],
                "departure_gate": flight_data["departure"]["gate"],
                "departure_delay": flight_data["departure"]["delay"],
                "departure_scheduled": flight_data["departure"]["scheduled"],
                "departure_estimated": flight_data["departure"]["estimated"],
                "departure_actual": flight_data["departure"]["actual"],
                "departure_estimated_runway": flight_data["departure"]["estimated_runway"],
                "departure_actual_runway": flight_data["departure"]["actual_runway"],
                "arrival_airport": flight_data["arrival"]["airport"],
                "arrival_timezone": flight_data["arrival"]["timezone"],
                "arrival_iata": flight_data["arrival"]["iata"],
                "arrival_icao": flight_data["arrival"]["icao"],
                "arrival_terminal": flight_data["arrival"]["terminal"],
                "arrival_gate": flight_data["arrival"]["gate"],
                "arrival_baggage": flight_data["arrival"]["baggage"],
                "arrival_delay": flight_data["arrival"]["delay"],
                "arrival_scheduled": flight_data["arrival"]["scheduled"],
                "arrival_estimated": flight_data["arrival"]["estimated"],
                "arrival_actual": flight_data["arrival"]["actual"],
                "arrival_estimated_runway": flight_data["arrival"]["estimated_runway"],
                "arrival_actual_runway": flight_data["arrival"]["actual_runway"],
                "airline_name": flight_data["airline"]["name"],
                "airline_iata": flight_data["airline"]["iata"],
                "airline_icao": flight_data["airline"]["icao"],
                "flight_number": flight_data["flight"]["number"],
                "flight_iata": flight_data["flight"]["iata"],
                "flight_icao": flight_data["flight"]["icao"],
                "codeshared": flight_data["flight"]["codeshared"],
            })

        offset += limit
        print(f'loaded {offset} data')
    df = pd.DataFrame(all_data)

    # Save the DataFrame as a new CSV file with timestamp
    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
    csv_file_name = f'flight_{timestamp}.csv'
    df.to_csv(csv_file_name, index=False)
    print(f"CSV file {csv_file_name} saved successfully.")

    return df

date_param = '2020-12-11' 
# Call the function to extract flights
extract_flights()
# Out:
# loaded 100 data
# loaded 200 data
# loaded 300 data
# loaded 400 data
# loaded 500 data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 86
#      84 date_param = '2020-12-11'
#      85 # Call the function to extract flights
# ---> 86 extract_flights()
#
# Cell In[56], line 21, in extract_flights()
#      19 while True:
#      20     params = {'access_key': api_key, 'limit': limit, 'offset': offset }
# ---> 21     api_result = requests.get('http://api.aviationstack.com/v1/flights', params)
#      22     data = api_result.json()
#      24     # Check if the 'data' key exists in the response
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
# ...

# %%
today  = datetime.now().strftime('%Y-%m-%d')
print(today)
# Out:
# 2024-03-08

# %%
{'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 285203}, 'data': [{'flight_date': '2024-03-09', 'flight_status': 'landed', 'departure': {'airport': 'Hobart', 'timezone': 'Australia/Hobart', 'iata': 'HBA', 'icao': 'YMHB', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T07:00:00+00:00', 'estimated': '2024-03-09T07:00:00+00:00', 'actual': '2024-03-08T06:33:00+00:00', 'estimated_runway': '2024-03-08T06:33:00+00:00', 'actual_runway': '2024-03-08T06:33:00+00:00'}, 'arrival': {'airport': 'Launceston', 'timezone': 'Australia/Hobart', 'iata': 'LST', 'icao': 'YMLT', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:22:00+00:00', 'estimated': '2024-03-08T07:22:00+00:00', 'actual': '2024-03-08T06:54:00+00:00', 'estimated_runway': '2024-03-08T06:54:00+00:00', 'actual_runway': '2024-03-08T06:54:00+00:00'}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-09', 'flight_status': 'landed', 'departure': {'airport': 'Melbourne - Tullamarine Airport', 'timezone': 'Australia/Melbourne', 'iata': 'MEL', 'icao': 'YMML', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T04:10:00+00:00', 'estimated': '2024-03-09T04:10:00+00:00', 'actual': '2024-03-08T03:55:00+00:00', 'estimated_runway': '2024-03-08T03:55:00+00:00', 'actual_runway': '2024-03-08T03:55:00+00:00'}, 'arrival': {'airport': 'Launceston', 'timezone': 'Australia/Hobart', 'iata': 'LST', 'icao': 'YMLT', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:20:00+00:00', 'estimated': '2024-03-08T05:20:00+00:00', 'actual': '2024-03-08T05:02:00+00:00', 'estimated_runway': '2024-03-08T05:02:00+00:00', 'actual_runway': '2024-03-08T05:02:00+00:00'}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-09', 'flight_status': 'landed', 'departure': {'airport': 'Launceston', 'timezone': 'Australia/Hobart', 'iata': 'LST', 'icao': 'YMLT', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T05:55:00+00:00', 'estimated': '2024-03-09T05:55:00+00:00', 'actual': '2024-03-08T05:38:00+00:00', 'estimated_runway': '2024-03-08T05:38:00+00:00', 'actual_runway': '2024-03-08T05:38:00+00:00'}, 'arrival': {'airport': 'Hobart', 'timezone': 'Australia/Hobart', 'iata': 'HBA', 'icao': 'YMHB', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T06:18:00+00:00', 'estimated': '2024-03-08T06:18:00+00:00', 'actual': '2024-03-08T06:02:00+00:00', 'estimated_runway': '2024-03-08T06:02:00+00:00', 'actual_runway': '2024-03-08T06:02:00+00:00'}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-09', 'flight_status': 'scheduled', 'departure': {'airport': 'Brisbane International', 'timezone': 'Australia/Brisbane', 'iata': 'BNE', 'icao': 'YBBN', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T00:15:00+00:00', 'estimated': '2024-03-09T00:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Rockhampton', 'timezone': 'Australia/Brisbane', 'iata': 'ROK', 'icao': 'YBRK', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T01:40:00+00:00', 'estimated': '2024-03-08T01:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-09', 'flight_status': 'landed', 'departure': {'airport': 'Brisbane International', 'timezone': 'Australia/Brisbane', 'iata': 'BNE', 'icao': 'YBBN', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-09T00:15:00+00:00', 'estimated': '2024-03-09T00:15:00+00:00', 'actual': '2024-03-08T00:31:00+00:00', 'estimated_runway': '2024-03-08T00:31:00+00:00', 'actual_runway': '2024-03-08T00:31:00+00:00'}, 'arrival': {'airport': 'Rockhampton', 'timezone': 'Australia/Brisbane', 'iata': 'ROK', 'icao': 'YBRK', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': 1, 'scheduled': '2024-03-08T01:40:00+00:00', 'estimated': '2024-03-08T01:40:00+00:00', 'actual': '2024-03-08T01:41:00+00:00', 'estimated_runway': '2024-03-08T01:41:00+00:00', 'actual_runway': '2024-03-08T01:41:00+00:00'}, 'airline': {'name': 'Thai AirAsia', 'iata': 'FD', 'icao': 'AIQ'}, 'flight': {'number': '449', 'iata': 'FD449', 'icao': 'AIQ449', 'codeshared': None}, 'aircraft': {'registration': 'VH-FDF', 'iata': 'B350', 'icao': 'B350', 'icao24': '7C19C1'}, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': 'F3', 'delay': 21, 'scheduled': '2024-03-08T01:55:00+00:00', 'estimated': '2024-03-08T01:55:00+00:00', 'actual': '2024-03-08T02:16:00+00:00', 'estimated_runway': '2024-03-08T02:16:00+00:00', 'actual_runway': '2024-03-08T02:16:00+00:00'}, 'arrival': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '1', 'gate': None, 'baggage': '15', 'delay': 2, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': '2024-03-08T06:51:00+00:00', 'estimated_runway': '2024-03-08T06:51:00+00:00', 'actual_runway': '2024-03-08T06:51:00+00:00'}, 'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'}, 'flight': {'number': '548', 'iata': 'MU548', 'icao': 'CES548', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'unknown', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:50:00+00:00', 'estimated': '2024-03-08T01:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shenzhen', 'timezone': 'Asia/Shanghai', 'iata': 'SZX', 'icao': 'ZGSZ', 'terminal': 'T3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:50:00+00:00', 'estimated': '2024-03-08T05:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Suparna Airlines', 'iata': 'Y8', 'icao': 'YZR'}, 'flight': {'number': '7474', 'iata': 'Y87474', 'icao': 'YZR7474', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'delay': 51, 'scheduled': '2024-03-08T01:50:00+00:00', 'estimated': '2024-03-08T01:50:00+00:00', 'actual': '2024-03-08T02:40:00+00:00', 'estimated_runway': '2024-03-08T02:40:00+00:00', 'actual_runway': '2024-03-08T02:40:00+00:00'}, 'arrival': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': '1', 'gate': '26', 'baggage': '4', 'delay': 14, 'scheduled': '2024-03-08T09:20:00+00:00', 'estimated': '2024-03-08T09:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Asiana Airlines', 'iata': 'OZ', 'icao': 'AAR'}, 'flight': {'number': '744', 'iata': 'OZ744', 'icao': 'AAR744', 'codeshared': None}, 'aircraft': {'registration': 'HL7740', 'iata': 'A333', 'icao': 'A333', 'icao24': '71BF40'}, 'live': {'updated': '2024-03-08T00:01:52+00:00', 'latitude': 34.5832, 'longitude': 126.807, 'altitude': 8846.82, 'direction': 5.44, 'speed_horizontal': 781.344, 'speed_vertical': -1.188, 'is_ground': False}}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': 'L,R', 'delay': 8, 'scheduled': '2024-03-08T01:50:00+00:00', 'estimated': '2024-03-08T01:50:00+00:00', 'actual': '2024-03-08T01:57:00+00:00', 'estimated_runway': '2024-03-08T01:57:00+00:00', 'actual_runway': '2024-03-08T01:57:00+00:00'}, 'arrival': {'airport': 'Nanjing Lukou International Airport', 'timezone': 'Asia/Shanghai', 'iata': 'NKG', 'icao': 'ZSNJ', 'terminal': '2', 'gate': None, 'baggage': '3', 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T06:28:00+00:00', 'estimated_runway': '2024-03-08T06:28:00+00:00', 'actual_runway': '2024-03-08T06:28:00+00:00'}, 'airline': {'name': 'Juneyao Airlines', 'iata': 'HO', 'icao': 'DKH'}, 'flight': {'number': '1638', 'iata': 'HO1638', 'icao': 'DKH1638', 'codeshared': None}, 'aircraft': {'registration': 'B-8036', 'iata': 'A321', 'icao': 'A321', 'icao24': '780E39'}, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:45:00+00:00', 'estimated': '2024-03-08T01:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Daguocun', 'timezone': 'Asia/Shanghai', 'iata': 'SJW', 'icao': 'ZBSJ', 'terminal': 'T2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T04:15:00+00:00', 'estimated': '2024-03-08T04:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'YTO Cargo Airlines', 'iata': 'YG', 'icao': 'HYT'}, 'flight': {'number': '9008', 'iata': 'YG9008', 'icao': 'HYT9008', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:45:00+00:00', 'estimated': '2024-03-08T01:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Guangzhou Baiyun International', 'timezone': 'Asia/Shanghai', 'iata': 'CAN', 'icao': 'ZGGG', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:35:00+00:00', 'estimated': '2024-03-08T05:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Longhao Airlines', 'iata': 'GI', 'icao': 'LHA'}, 'flight': {'number': '4230', 'iata': 'GI4230', 'icao': 'LHA4230', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': 'F,H', 'delay': 48, 'scheduled': '2024-03-08T01:40:00+00:00', 'estimated': '2024-03-08T01:40:00+00:00', 'actual': '2024-03-08T02:24:00+00:00', 'estimated_runway': '2024-03-08T02:24:00+00:00', 'actual_runway': '2024-03-08T02:24:00+00:00'}, 'arrival': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '2', 'gate': None, 'baggage': '24', 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T06:54:00+00:00', 'estimated_runway': '2024-03-08T06:54:00+00:00', 'actual_runway': '2024-03-08T06:54:00+00:00'}, 'airline': {'name': 'Air China LTD', 'iata': 'CA', 'icao': 'CCA'}, 'flight': {'number': '806', 'iata': 'CA806', 'icao': 'CCA806', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'delay': 29, 'scheduled': '2024-03-08T01:40:00+00:00', 'estimated': '2024-03-08T01:40:00+00:00', 'actual': '2024-03-08T02:36:00+00:00', 'estimated_runway': '2024-03-08T02:36:00+00:00', 'actual_runway': '2024-03-08T02:36:00+00:00'}, 'arrival': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': '2', 'gate': '242', 'baggage': '3', 'delay': 15, 'scheduled': '2024-03-08T08:55:00+00:00', 'estimated': '2024-03-08T08:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Korean Air', 'iata': 'KE', 'icao': 'KAL'}, 'flight': {'number': '674', 'iata': 'KE674', 'icao': 'KAL674', 'codeshared': None}, 'aircraft': {'registration': 'HL8390', 'iata': 'B789', 'icao': 'B789', 'icao24': '71C390'}, 'live': {'updated': '2024-03-08T00:08:53+00:00', 'latitude': 37.0415, 'longitude': 126.558, 'altitude': 129.54, 'direction': 325.15, 'speed_horizontal': 252.756, 'speed_vertical': -12.888, 'is_ground': False}}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shenzhen', 'timezone': 'Asia/Shanghai', 'iata': 'SZX', 'icao': 'ZGSZ', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T13:05:00+00:00', 'estimated': '2024-03-08T13:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Zhengzhou', 'timezone': 'Asia/Shanghai', 'iata': 'CGO', 'icao': 'ZHCC', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T15:35:00+00:00', 'estimated': '2024-03-08T15:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Donghai Airlines', 'iata': 'DZ', 'icao': 'EPA'}, 'flight': {'number': '6243', 'iata': 'DZ6243', 'icao': 'EPA6243', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Kansai International', 'timezone': 'Asia/Tokyo', 'iata': 'KIX', 'icao': 'RJBB', 'terminal': None, 'gate': None, 'delay': 360, 'scheduled': '2024-03-08T01:10:00+00:00', 'estimated': '2024-03-08T01:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Lishe International Airport', 'timezone': 'Asia/Shanghai', 'iata': 'NGB', 'icao': 'ZSNB', 'terminal': 'T2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T03:00:00+00:00', 'estimated': '2024-03-08T03:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Longhao Airlines', 'iata': 'GI', 'icao': 'LHA'}, 'flight': {'number': '4116', 'iata': 'GI4116', 'icao': 'LHA4116', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'unknown', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:10:00+00:00', 'estimated': '2024-03-08T03:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Frans Kaisepo', 'timezone': 'Asia/Jayapura', 'iata': 'BIK', 'icao': 'WABB', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Sriwijaya Air', 'iata': 'SJ', 'icao': 'SJY'}, 'flight': {'number': '582', 'iata': 'SJ582', 'icao': 'SJY582', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:15:00+00:00', 'estimated': '2024-03-08T03:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Frans Kaisepo', 'timezone': 'Asia/Jayapura', 'iata': 'BIK', 'icao': 'WABB', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:05:00+00:00', 'estimated': '2024-03-08T07:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}, 'flight': {'number': '800', 'iata': 'JT800', 'icao': 'LNI800', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:15:00+00:00', 'estimated': '2024-03-08T03:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Frans Kaisepo', 'timezone': 'Asia/Jayapura', 'iata': 'BIK', 'icao': 'WABB', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:05:00+00:00', 'estimated': '2024-03-08T07:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}, 'flight': {'number': '1880', 'iata': 'JT1880', 'icao': 'LNI1880', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Albury', 'timezone': 'Australia/Sydney', 'iata': 'ABX', 'icao': 'YMAY', 'terminal': None, 'gate': None, 'delay': 30, 'scheduled': '2024-03-08T10:05:00+00:00', 'estimated': '2024-03-08T10:05:00+00:00', 'actual': '2024-03-08T10:34:00+00:00', 'estimated_runway': '2024-03-08T10:34:00+00:00', 'actual_runway': '2024-03-08T10:34:00+00:00'}, 'arrival': {'airport': 'Sydney Kingsford Smith Airport', 'timezone': 'Australia/Sydney', 'iata': 'SYD', 'icao': 'YSSY', 'terminal': '3', 'gate': '1', 'baggage': 'QFR', 'delay': 5, 'scheduled': '2024-03-08T11:20:00+00:00', 'estimated': '2024-03-08T11:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'QantasLink', 'iata': None, 'icao': 'QLK'}, 'flight': {'number': '2204', 'iata': None, 'icao': 'QLK2204', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Soekarno-Hatta International', 'timezone': 'Asia/Jakarta', 'iata': 'CGK', 'icao': 'WIII', 'terminal': '3', 'gate': 'C22', 'delay': 7, 'scheduled': '2024-03-08T01:45:00+00:00', 'estimated': '2024-03-08T01:45:00+00:00', 'actual': '2024-03-08T01:51:00+00:00', 'estimated_runway': '2024-03-08T01:51:00+00:00', 'actual_runway': '2024-03-08T01:51:00+00:00'}, 'arrival': {'airport': 'Pattimura', 'timezone': 'Asia/Jayapura', 'iata': 'AMQ', 'icao': 'WAPP', 'terminal': '2', 'gate': '3', 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:20:00+00:00', 'estimated': '2024-03-08T07:20:00+00:00', 'actual': '2024-03-08T07:03:00+00:00', 'estimated_runway': '2024-03-08T07:03:00+00:00', 'actual_runway': '2024-03-08T07:03:00+00:00'}, 'airline': {'name': 'Citilink', 'iata': 'QG', 'icao': 'CTV'}, 'flight': {'number': '210', 'iata': 'QG210', 'icao': 'CTV210', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Jeju Airport', 'timezone': 'Asia/Seoul', 'iata': 'CJU', 'icao': 'RKPC', 'terminal': None, 'gate': '12', 'delay': None, 'scheduled': '2024-03-08T12:25:00+00:00', 'estimated': '2024-03-08T12:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Gwangju', 'timezone': 'Asia/Seoul', 'iata': 'KWJ', 'icao': 'RKJJ', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T13:25:00+00:00', 'estimated': '2024-03-08T13:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Jin Air', 'iata': 'LJ', 'icao': 'JNA'}, 'flight': {'number': '452', 'iata': 'LJ452', 'icao': 'JNA452', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shang-Yi', 'timezone': 'Asia/Taipei', 'iata': 'KNH', 'icao': 'RCBS', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T09:00:00+00:00', 'estimated': '2024-03-08T09:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kaoshiung International Airport', 'timezone': 'Asia/Taipei', 'iata': 'KHH', 'icao': 'RCKH', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:00:00+00:00', 'estimated': '2024-03-08T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Mandarin Airlines', 'iata': 'AE', 'icao': 'MDA'}, 'flight': {'number': '302', 'iata': 'AE302', 'icao': 'MDA302', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Singapore Changi', 'timezone': 'Asia/Singapore', 'iata': 'SIN', 'icao': 'WSSS', 'terminal': '2', 'gate': 'F41', 'delay': 18, 'scheduled': '2024-03-08T00:05:00+00:00', 'estimated': '2024-03-08T00:05:00+00:00', 'actual': '2024-03-08T00:23:00+00:00', 'estimated_runway': '2024-03-08T00:23:00+00:00', 'actual_runway': '2024-03-08T00:23:00+00:00'}, 'arrival': {'airport': 'Zurich', 'timezone': 'Europe/Zurich', 'iata': 'ZRH', 'icao': 'LSZH', 'terminal': '2', 'gate': 'E26', 'baggage': None, 'delay': 16, 'scheduled': '2024-03-08T06:10:00+00:00', 'estimated': '2024-03-08T06:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}, 'flight': {'number': '177', 'iata': 'LX177', 'icao': 'SWR177', 'codeshared': None}, 'aircraft': {'registration': 'HB-JNC', 'iata': 'B77W', 'icao': 'B77W', 'icao24': '4B1918'}, 'live': {'updated': '2024-03-07T22:11:19+00:00', 'latitude': 26.2797, 'longitude': 64.2106, 'altitude': 9753.6, 'direction': 317, 'speed_horizontal': 751.912, 'speed_vertical': 0, 'is_ground': False}}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:20:00+00:00', 'estimated': '2024-03-08T03:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Timika', 'timezone': 'Asia/Jayapura', 'iata': 'TIM', 'icao': 'WAYY', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:15:00+00:00', 'estimated': '2024-03-08T07:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Sriwijaya Air', 'iata': 'SJ', 'icao': 'SJY'}, 'flight': {'number': '588', 'iata': 'SJ588', 'icao': 'SJY588', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': 'D', 'gate': '5', 'delay': 131, 'scheduled': '2024-03-08T03:35:00+00:00', 'estimated': '2024-03-08T03:35:00+00:00', 'actual': '2024-03-08T05:45:00+00:00', 'estimated_runway': '2024-03-08T05:45:00+00:00', 'actual_runway': '2024-03-08T05:45:00+00:00'}, 'arrival': {'airport': 'Jefman', 'timezone': 'Asia/Jayapura', 'iata': 'SOQ', 'icao': 'WASS', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': 113, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': None, 'iata': 'X1', 'icao': 'X1'}, 'flight': {'number': '6190', 'iata': 'X16190', 'icao': 'X16190', 'codeshared': {'airline_name': 'lion air', 'airline_iata': 'jt', 'airline_icao': 'lni', 'flight_number': '942', 'flight_iata': 'jt942', 'flight_icao': 'lni942'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': 'D', 'gate': '5', 'delay': 131, 'scheduled': '2024-03-08T03:35:00+00:00', 'estimated': '2024-03-08T03:35:00+00:00', 'actual': '2024-03-08T05:45:00+00:00', 'estimated_runway': '2024-03-08T05:45:00+00:00', 'actual_runway': '2024-03-08T05:45:00+00:00'}, 'arrival': {'airport': 'Jefman', 'timezone': 'Asia/Jayapura', 'iata': 'SOQ', 'icao': 'WASS', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': 113, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}, 'flight': {'number': '942', 'iata': 'JT942', 'icao': 'LNI942', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:35:00+00:00', 'estimated': '2024-03-08T03:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Jefman', 'timezone': 'Asia/Jayapura', 'iata': 'SOQ', 'icao': 'WASS', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Lion Air', 'iata': 'JT', 'icao': 'LNI'}, 'flight': {'number': '3800', 'iata': 'JT3800', 'icao': 'LNI3800', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hasanudin', 'timezone': 'Asia/Makassar', 'iata': 'UPG', 'icao': 'WAAA', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T04:00:00+00:00', 'estimated': '2024-03-08T04:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Jefman', 'timezone': 'Asia/Jayapura', 'iata': 'SOQ', 'icao': 'WASS', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:15:00+00:00', 'estimated': '2024-03-08T07:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Sriwijaya Air', 'iata': 'SJ', 'icao': 'SJY'}, 'flight': {'number': '570', 'iata': 'SJ570', 'icao': 'SJY570', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '1', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T12:00:00+00:00', 'estimated': '2024-03-08T12:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Schiphol', 'timezone': 'Europe/Amsterdam', 'iata': 'AMS', 'icao': 'EHAM', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T17:15:00+00:00', 'estimated': '2024-03-08T17:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'}, 'flight': {'number': '771', 'iata': 'MU771', 'icao': 'CES771', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Palese', 'timezone': 'Europe/Rome', 'iata': 'BRI', 'icao': 'LIBD', 'terminal': None, 'gate': None, 'delay': 18, 'scheduled': '2024-03-08T06:20:00+00:00', 'estimated': '2024-03-08T06:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)', 'timezone': 'Europe/Rome', 'iata': 'FCO', 'icao': 'LIRF', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:30:00+00:00', 'estimated': '2024-03-08T07:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Kuwait Airways', 'iata': 'KU', 'icao': 'KAC'}, 'flight': {'number': '6278', 'iata': 'KU6278', 'icao': 'KAC6278', 'codeshared': {'airline_name': 'ita airways', 'airline_iata': 'az', 'airline_icao': 'ity', 'flight_number': '1602', 'flight_iata': 'az1602', 'flight_icao': 'ity1602'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Helsinki-vantaa', 'timezone': 'Europe/Helsinki', 'iata': 'HEL', 'icao': 'EFHK', 'terminal': '2', 'gate': '36', 'delay': 10, 'scheduled': '2024-03-08T07:40:00+00:00', 'estimated': '2024-03-08T07:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Tromso/langnes', 'timezone': 'Europe/Oslo', 'iata': 'TOS', 'icao': 'ENTC', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T08:30:00+00:00', 'estimated': '2024-03-08T08:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Jet Linx Aviation', 'iata': 'JL', 'icao': 'JTL'}, 'flight': {'number': '9399', 'iata': 'JL9399', 'icao': 'JTL9399', 'codeshared': {'airline_name': 'finnair', 'airline_iata': 'ay', 'airline_icao': 'fin', 'flight_number': '935', 'flight_iata': 'ay935', 'flight_icao': 'fin935'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Bauerfield', 'timezone': 'Pacific/Efate', 'iata': 'VLI', 'icao': 'NVVV', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T16:10:00+00:00', 'estimated': '2024-03-08T16:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Brisbane International', 'timezone': 'Australia/Brisbane', 'iata': 'BNE', 'icao': 'YBBN', 'terminal': 'I', 'gate': '84', 'baggage': 'I07', 'delay': None, 'scheduled': '2024-03-08T18:05:00+00:00', 'estimated': '2024-03-08T18:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'}, 'flight': {'number': '6373', 'iata': 'SQ6373', 'icao': 'SIA6373', 'codeshared': {'airline_name': 'virgin australia', 'airline_iata': 'va', 'airline_icao': 'voz', 'flight_number': '56', 'flight_iata': 'va56', 'flight_icao': 'voz56'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Bandaranaike International', 'timezone': 'Asia/Colombo', 'iata': 'CMB', 'icao': 'VCBI', 'terminal': None, 'gate': '06', 'delay': 77, 'scheduled': '2024-03-08T00:40:00+00:00', 'estimated': '2024-03-08T00:40:00+00:00', 'actual': '2024-03-08T01:56:00+00:00', 'estimated_runway': '2024-03-08T01:56:00+00:00', 'actual_runway': '2024-03-08T01:56:00+00:00'}, 'arrival': {'airport': 'Kuala Lumpur International Airport (klia)', 'timezone': 'Asia/Kuala_Lumpur', 'iata': 'KUL', 'icao': 'WMKK', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': 60, 'scheduled': '2024-03-08T06:55:00+00:00', 'estimated': '2024-03-08T06:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Etihad Airways', 'iata': 'EY', 'icao': 'ETD'}, 'flight': {'number': '7160', 'iata': 'EY7160', 'icao': 'ETD7160', 'codeshared': {'airline_name': 'srilankan airlines', 'airline_iata': 'ul', 'airline_icao': 'alk', 'flight_number': '318', 'flight_iata': 'ul318', 'flight_icao': 'alk318'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Yancheng', 'timezone': 'Asia/Shanghai', 'iata': 'YNZ', 'icao': 'ZSYN', 'terminal': None, 'gate': '8-11', 'delay': 17, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T07:13:00+00:00', 'estimated_runway': '2024-03-08T07:13:00+00:00', 'actual_runway': '2024-03-08T07:13:00+00:00'}, 'arrival': {'airport': 'Shenzhen', 'timezone': 'Asia/Shanghai', 'iata': 'SZX', 'icao': 'ZGSZ', 'terminal': 'T3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T09:40:00+00:00', 'estimated': '2024-03-08T09:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'}, 'flight': {'number': '8588', 'iata': 'CZ8588', 'icao': 'CSN8588', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Kuching', 'timezone': 'Asia/Kuching', 'iata': 'KCH', 'icao': 'WBGG', 'terminal': None, 'gate': None, 'delay': 8, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': '2024-03-08T06:57:00+00:00', 'estimated_runway': '2024-03-08T06:57:00+00:00', 'actual_runway': '2024-03-08T06:57:00+00:00'}, 'arrival': {'airport': 'Kuala Lumpur International Airport (klia)', 'timezone': 'Asia/Kuala_Lumpur', 'iata': 'KUL', 'icao': 'WMKK', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T08:40:00+00:00', 'estimated': '2024-03-08T08:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Philippine Airlines', 'iata': 'PR', 'icao': 'PAL'}, 'flight': {'number': '3527', 'iata': 'PR3527', 'icao': 'PAL3527', 'codeshared': {'airline_name': 'malaysia airlines', 'airline_iata': 'mh', 'airline_icao': 'mas', 'flight_number': '2505', 'flight_iata': 'mh2505', 'flight_icao': 'mas2505'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Weipa', 'timezone': 'Australia/Brisbane', 'iata': 'WEI', 'icao': 'YBWP', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T12:55:00+00:00', 'estimated': '2024-03-08T12:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Cairns', 'timezone': 'Australia/Brisbane', 'iata': 'CNS', 'icao': 'YBCS', 'terminal': '2', 'gate': '2', 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T14:20:00+00:00', 'estimated': '2024-03-08T14:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'}, 'flight': {'number': '2479', 'iata': 'QF2479', 'icao': 'QFA2479', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Adelaide International Airport', 'timezone': 'Australia/Adelaide', 'iata': 'ADL', 'icao': 'YPAD', 'terminal': '1', 'gate': '20', 'delay': 14, 'scheduled': '2024-03-08T06:00:00+00:00', 'estimated': '2024-03-08T06:00:00+00:00', 'actual': '2024-03-08T06:13:00+00:00', 'estimated_runway': '2024-03-08T06:13:00+00:00', 'actual_runway': '2024-03-08T06:13:00+00:00'}, 'arrival': {'airport': 'Sydney Kingsford Smith Airport', 'timezone': 'Australia/Sydney', 'iata': 'SYD', 'icao': 'YSSY', 'terminal': '3', 'gate': 'T3G', 'baggage': 'QFR', 'delay': 9, 'scheduled': '2024-03-08T08:25:00+00:00', 'estimated': '2024-03-08T08:25:00+00:00', 'actual': '2024-03-08T08:34:00+00:00', 'estimated_runway': '2024-03-08T08:34:00+00:00', 'actual_runway': '2024-03-08T08:34:00+00:00'}, 'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}, 'flight': {'number': '5730', 'iata': 'EK5730', 'icao': 'UAE5730', 'codeshared': {'airline_name': 'qantas', 'airline_iata': 'qf', 'airline_icao': 'qfa', 'flight_number': '730', 'flight_iata': 'qf730', 'flight_icao': 'qfa730'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Urumqi', 'timezone': 'Asia/Shanghai', 'iata': 'URC', 'icao': 'ZWWW', 'terminal': '2', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T10:05:00+00:00', 'estimated': '2024-03-08T10:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Guangzhou Baiyun International', 'timezone': 'Asia/Shanghai', 'iata': 'CAN', 'icao': 'ZGGG', 'terminal': '1', 'gate': None, 'baggage': '8', 'delay': None, 'scheduled': '2024-03-08T15:15:00+00:00', 'estimated': '2024-03-08T15:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Urumqi Airlines', 'iata': 'UQ', 'icao': 'CUH'}, 'flight': {'number': '2591', 'iata': 'UQ2591', 'icao': 'CUH2591', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Haneda Airport', 'timezone': 'Asia/Tokyo', 'iata': 'HND', 'icao': 'RJTT', 'terminal': '1', 'gate': '9', 'delay': None, 'scheduled': '2024-03-08T11:55:00+00:00', 'estimated': '2024-03-08T11:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Naha', 'timezone': 'Asia/Tokyo', 'iata': 'OKA', 'icao': 'ROAH', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T14:40:00+00:00', 'estimated': '2024-03-08T14:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'JAL', 'iata': 'JL', 'icao': 'JAL'}, 'flight': {'number': '915', 'iata': 'JL915', 'icao': 'JAL915', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Auckland International', 'timezone': 'Pacific/Auckland', 'iata': 'AKL', 'icao': 'NZAA', 'terminal': 'D', 'gate': '31', 'delay': 15, 'scheduled': '2024-03-08T11:35:00+00:00', 'estimated': '2024-03-08T11:35:00+00:00', 'actual': '2024-03-08T11:50:00+00:00', 'estimated_runway': '2024-03-08T11:50:00+00:00', 'actual_runway': '2024-03-08T11:50:00+00:00'}, 'arrival': {'airport': 'Queenstown', 'timezone': 'Pacific/Auckland', 'iata': 'ZQN', 'icao': 'NZQN', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T13:30:00+00:00', 'estimated': '2024-03-08T13:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'}, 'flight': {'number': '4451', 'iata': 'SQ4451', 'icao': 'SIA4451', 'codeshared': {'airline_name': 'air new zealand', 'airline_iata': 'nz', 'airline_icao': 'anz', 'flight_number': '619', 'flight_iata': 'nz619', 'flight_icao': 'anz619'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZUUU', 'terminal': '2', 'gate': 'J,K', 'delay': None, 'scheduled': '2024-03-08T10:00:00+00:00', 'estimated': '2024-03-08T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shanghai Hongqiao International', 'timezone': 'Asia/Shanghai', 'iata': 'SHA', 'icao': 'ZSSS', 'terminal': '2', 'gate': None, 'baggage': '30', 'delay': None, 'scheduled': '2024-03-08T12:35:00+00:00', 'estimated': '2024-03-08T12:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'}, 'flight': {'number': '5406', 'iata': 'MU5406', 'icao': 'CES5406', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'East Midlands', 'timezone': 'Europe/London', 'iata': 'EMA', 'icao': 'EGNX', 'terminal': None, 'gate': None, 'delay': 10, 'scheduled': '2024-03-08T01:35:00+00:00', 'estimated': '2024-03-08T01:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Exeter', 'timezone': 'Europe/London', 'iata': 'EXT', 'icao': 'EGTE', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T02:16:00+00:00', 'estimated': '2024-03-08T02:16:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'West Atlantic UK', 'iata': None, 'icao': 'NPT'}, 'flight': {'number': None, 'iata': None, 'icao': 'NPT', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Singapore Changi', 'timezone': 'Asia/Singapore', 'iata': 'SIN', 'icao': 'WSSS', 'terminal': '4', 'gate': 'G1', 'delay': None, 'scheduled': '2024-03-08T11:45:00+00:00', 'estimated': '2024-03-08T11:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Penang International', 'timezone': 'Asia/Kuala_Lumpur', 'iata': 'PEN', 'icao': 'WMKP', 'terminal': 'I', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T13:00:00+00:00', 'estimated': '2024-03-08T13:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'AirAsia', 'iata': 'AK', 'icao': 'AXM'}, 'flight': {'number': '1720', 'iata': 'AK1720', 'icao': 'AXM1720', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Cam Ranh', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'CXR', 'icao': 'VVCR', 'terminal': '2', 'gate': 'F', 'delay': 12, 'scheduled': '2024-03-08T00:40:00+00:00', 'estimated': '2024-03-08T00:40:00+00:00', 'actual': '2024-03-08T00:51:00+00:00', 'estimated_runway': '2024-03-08T00:51:00+00:00', 'actual_runway': '2024-03-08T00:51:00+00:00'}, 'arrival': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': '2', 'gate': '251', 'baggage': '6', 'delay': None, 'scheduled': '2024-03-08T07:55:00+00:00', 'estimated': '2024-03-08T07:55:00+00:00', 'actual': '2024-03-08T07:09:00+00:00', 'estimated_runway': '2024-03-08T07:09:00+00:00', 'actual_runway': '2024-03-08T07:09:00+00:00'}, 'airline': {'name': 'Jin Air', 'iata': 'LJ', 'icao': 'JNA'}, 'flight': {'number': '74', 'iata': 'LJ74', 'icao': 'JNA74', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Don Muang', 'timezone': 'Asia/Bangkok', 'iata': 'DMK', 'icao': 'VTBD', 'terminal': '1', 'gate': '6', 'delay': 18, 'scheduled': '2024-03-08T00:40:00+00:00', 'estimated': '2024-03-08T00:40:00+00:00', 'actual': '2024-03-08T00:58:00+00:00', 'estimated_runway': '2024-03-08T00:58:00+00:00', 'actual_runway': '2024-03-08T00:58:00+00:00'}, 'arrival': {'airport': 'Cheongju', 'timezone': 'Asia/Seoul', 'iata': 'CJJ', 'icao': 'RKTU', 'terminal': '3', 'gate': None, 'baggage': '1', 'delay': None, 'scheduled': '2024-03-08T07:55:00+00:00', 'estimated': '2024-03-08T07:55:00+00:00', 'actual': '2024-03-08T07:49:00+00:00', 'estimated_runway': '2024-03-08T07:49:00+00:00', 'actual_runway': '2024-03-08T07:49:00+00:00'}, 'airline': {'name': None, 'iata': 'H1', 'icao': 'H1'}, 'flight': {'number': '5929', 'iata': 'H15929', 'icao': 'H15929', 'codeshared': {'airline_name': "t'way air", 'airline_iata': 'tw', 'airline_icao': 'twb', 'flight_number': '184', 'flight_iata': 'tw184', 'flight_icao': 'twb184'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Don Muang', 'timezone': 'Asia/Bangkok', 'iata': 'DMK', 'icao': 'VTBD', 'terminal': '1', 'gate': '6', 'delay': 18, 'scheduled': '2024-03-08T00:40:00+00:00', 'estimated': '2024-03-08T00:40:00+00:00', 'actual': '2024-03-08T00:58:00+00:00', 'estimated_runway': '2024-03-08T00:58:00+00:00', 'actual_runway': '2024-03-08T00:58:00+00:00'}, 'arrival': {'airport': 'Cheongju', 'timezone': 'Asia/Seoul', 'iata': 'CJJ', 'icao': 'RKTU', 'terminal': '3', 'gate': None, 'baggage': '1', 'delay': None, 'scheduled': '2024-03-08T07:55:00+00:00', 'estimated': '2024-03-08T07:55:00+00:00', 'actual': '2024-03-08T07:49:00+00:00', 'estimated_runway': '2024-03-08T07:49:00+00:00', 'actual_runway': '2024-03-08T07:49:00+00:00'}, 'airline': {'name': "T'Way Air", 'iata': 'TW', 'icao': 'TWB'}, 'flight': {'number': '184', 'iata': 'TW184', 'icao': 'TWB184', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 12, 'scheduled': '2024-03-08T00:15:00+00:00', 'estimated': '2024-03-08T00:15:00+00:00', 'actual': '2024-03-08T00:27:00+00:00', 'estimated_runway': '2024-03-08T00:27:00+00:00', 'actual_runway': '2024-03-08T00:27:00+00:00'}, 'arrival': {'airport': 'Chu-Bu Centrair International (Central Japan International)', 'timezone': 'Asia/Tokyo', 'iata': 'NGO', 'icao': 'RJGG', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T06:30:00+00:00', 'estimated': '2024-03-08T06:30:00+00:00', 'actual': '2024-03-08T06:12:00+00:00', 'estimated_runway': '2024-03-08T06:12:00+00:00', 'actual_runway': '2024-03-08T06:12:00+00:00'}, 'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'}, 'flight': {'number': '9720', 'iata': 'NH9720', 'icao': 'ANA9720', 'codeshared': {'airline_name': 'vietnam airlines', 'airline_iata': 'vn', 'airline_icao': 'hvn', 'flight_number': '346', 'flight_iata': 'vn346', 'flight_icao': 'hvn346'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 12, 'scheduled': '2024-03-08T00:15:00+00:00', 'estimated': '2024-03-08T00:15:00+00:00', 'actual': '2024-03-08T00:27:00+00:00', 'estimated_runway': '2024-03-08T00:27:00+00:00', 'actual_runway': '2024-03-08T00:27:00+00:00'}, 'arrival': {'airport': 'Chu-Bu Centrair International (Central Japan International)', 'timezone': 'Asia/Tokyo', 'iata': 'NGO', 'icao': 'RJGG', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T06:30:00+00:00', 'estimated': '2024-03-08T06:30:00+00:00', 'actual': '2024-03-08T06:12:00+00:00', 'estimated_runway': '2024-03-08T06:12:00+00:00', 'actual_runway': '2024-03-08T06:12:00+00:00'}, 'airline': {'name': 'Vietnam Airlines', 'iata': 'VN', 'icao': 'HVN'}, 'flight': {'number': '346', 'iata': 'VN346', 'icao': 'HVN346', 'codeshared': None}, 'aircraft': {'registration': 'VN-A624', 'iata': 'A21N', 'icao': 'A21N', 'icao24': '88816F'}, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 26, 'scheduled': '2024-03-08T00:20:00+00:00', 'estimated': '2024-03-08T00:20:00+00:00', 'actual': '2024-03-08T00:46:00+00:00', 'estimated_runway': '2024-03-08T00:46:00+00:00', 'actual_runway': '2024-03-08T00:46:00+00:00'}, 'arrival': {'airport': 'Narita International Airport', 'timezone': 'Asia/Tokyo', 'iata': 'NRT', 'icao': 'RJAA', 'terminal': '1N', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T06:44:00+00:00', 'estimated_runway': '2024-03-08T06:44:00+00:00', 'actual_runway': '2024-03-08T06:44:00+00:00'}, 'airline': {'name': 'ANA', 'iata': 'NH', 'icao': 'ANA'}, 'flight': {'number': '9716', 'iata': 'NH9716', 'icao': 'ANA9716', 'codeshared': {'airline_name': 'vietnam airlines', 'airline_iata': 'vn', 'airline_icao': 'hvn', 'flight_number': '310', 'flight_iata': 'vn310', 'flight_icao': 'hvn310'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 26, 'scheduled': '2024-03-08T00:20:00+00:00', 'estimated': '2024-03-08T00:20:00+00:00', 'actual': '2024-03-08T00:46:00+00:00', 'estimated_runway': '2024-03-08T00:46:00+00:00', 'actual_runway': '2024-03-08T00:46:00+00:00'}, 'arrival': {'airport': 'Narita International Airport', 'timezone': 'Asia/Tokyo', 'iata': 'NRT', 'icao': 'RJAA', 'terminal': '1N', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T06:44:00+00:00', 'estimated_runway': '2024-03-08T06:44:00+00:00', 'actual_runway': '2024-03-08T06:44:00+00:00'}, 'airline': {'name': 'Vietnam Airlines', 'iata': 'VN', 'icao': 'HVN'}, 'flight': {'number': '310', 'iata': 'VN310', 'icao': 'HVN310', 'codeshared': None}, 'aircraft': {'registration': 'VN-A891', 'iata': 'A359', 'icao': 'A359', 'icao24': '888124'}, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 35, 'scheduled': '2024-03-08T00:20:00+00:00', 'estimated': '2024-03-08T00:20:00+00:00', 'actual': '2024-03-08T00:55:00+00:00', 'estimated_runway': '2024-03-08T00:55:00+00:00', 'actual_runway': '2024-03-08T00:55:00+00:00'}, 'arrival': {'airport': 'Gimhae', 'timezone': 'Asia/Seoul', 'iata': 'PUS', 'icao': 'RKPK', 'terminal': 'I', 'gate': None, 'baggage': None, 'delay': 10, 'scheduled': '2024-03-08T06:10:00+00:00', 'estimated': '2024-03-08T06:10:00+00:00', 'actual': '2024-03-08T06:14:00+00:00', 'estimated_runway': '2024-03-08T06:14:00+00:00', 'actual_runway': '2024-03-08T06:14:00+00:00'}, 'airline': {'name': 'Korean Air', 'iata': 'KE', 'icao': 'KAL'}, 'flight': {'number': '5686', 'iata': 'KE5686', 'icao': 'KAL5686', 'codeshared': {'airline_name': 'vietnam airlines', 'airline_iata': 'vn', 'airline_icao': 'hvn', 'flight_number': '426', 'flight_iata': 'vn426', 'flight_icao': 'hvn426'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 35, 'scheduled': '2024-03-08T00:20:00+00:00', 'estimated': '2024-03-08T00:20:00+00:00', 'actual': '2024-03-08T00:55:00+00:00', 'estimated_runway': '2024-03-08T00:55:00+00:00', 'actual_runway': '2024-03-08T00:55:00+00:00'}, 'arrival': {'airport': 'Gimhae', 'timezone': 'Asia/Seoul', 'iata': 'PUS', 'icao': 'RKPK', 'terminal': 'I', 'gate': None, 'baggage': None, 'delay': 10, 'scheduled': '2024-03-08T06:10:00+00:00', 'estimated': '2024-03-08T06:10:00+00:00', 'actual': '2024-03-08T06:14:00+00:00', 'estimated_runway': '2024-03-08T06:14:00+00:00', 'actual_runway': '2024-03-08T06:14:00+00:00'}, 'airline': {'name': 'Vietnam Airlines', 'iata': 'VN', 'icao': 'HVN'}, 'flight': {'number': '426', 'iata': 'VN426', 'icao': 'HVN426', 'codeshared': None}, 'aircraft': {'registration': 'VN-A625', 'iata': 'A21N', 'icao': 'A21N', 'icao24': '888170'}, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': 19, 'scheduled': '2024-03-08T00:25:00+00:00', 'estimated': '2024-03-08T00:25:00+00:00', 'actual': '2024-03-08T00:43:00+00:00', 'estimated_runway': '2024-03-08T00:43:00+00:00', 'actual_runway': '2024-03-08T00:43:00+00:00'}, 'arrival': {'airport': 'Narita International Airport', 'timezone': 'Asia/Tokyo', 'iata': 'NRT', 'icao': 'RJAA', 'terminal': '1S', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:00:00+00:00', 'estimated': '2024-03-08T07:00:00+00:00', 'actual': '2024-03-08T06:42:00+00:00', 'estimated_runway': '2024-03-08T06:42:00+00:00', 'actual_runway': '2024-03-08T06:42:00+00:00'}, 'airline': {'name': 'United Airlines', 'iata': 'UA', 'icao': 'UAL'}, 'flight': {'number': '7921', 'iata': 'UA7921', 'icao': 'UAL7921', 'codeshared': {'airline_name': 'ana', 'airline_iata': 'nh', 'airline_icao': 'ana', 'flight_number': '898', 'flight_iata': 'nh898', 'flight_icao': 'ana898'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Bundaberg', 'timezone': 'Australia/Brisbane', 'iata': 'BDB', 'icao': 'YBUD', 'terminal': None, 'gate': None, 'delay': 19, 'scheduled': '2024-03-08T08:30:00+00:00', 'estimated': '2024-03-08T08:30:00+00:00', 'actual': '2024-03-08T08:48:00+00:00', 'estimated_runway': '2024-03-08T08:48:00+00:00', 'actual_runway': '2024-03-08T08:48:00+00:00'}, 'arrival': {'airport': 'Hamilton Island', 'timezone': 'Australia/Lindeman', 'iata': 'HTI', 'icao': 'YBHM', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': 28, 'scheduled': '2024-03-08T09:20:00+00:00', 'estimated': '2024-03-08T09:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'empty', 'iata': None, 'icao': None}, 'flight': {'number': None, 'iata': None, 'icao': None, 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Soekarno-Hatta International', 'timezone': 'Asia/Jakarta', 'iata': 'CGK', 'icao': 'WIII', 'terminal': '3', 'gate': None, 'delay': 11, 'scheduled': '2024-03-08T00:50:00+00:00', 'estimated': '2024-03-08T00:50:00+00:00', 'actual': '2024-03-08T01:00:00+00:00', 'estimated_runway': '2024-03-08T01:00:00+00:00', 'actual_runway': '2024-03-08T01:00:00+00:00'}, 'arrival': {'airport': 'Jefman', 'timezone': 'Asia/Jayapura', 'iata': 'SOQ', 'icao': 'WASS', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': 54, 'scheduled': '2024-03-08T06:50:00+00:00', 'estimated': '2024-03-08T06:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Pelita Air', 'iata': 'IP', 'icao': 'PAS'}, 'flight': {'number': '920', 'iata': 'IP920', 'icao': 'PAS920', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Kuala Lumpur International Airport (klia)', 'timezone': 'Asia/Kuala_Lumpur', 'iata': 'KUL', 'icao': 'WMKK', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:45:00+00:00', 'estimated': '2024-03-08T01:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shenzhen', 'timezone': 'Asia/Shanghai', 'iata': 'SZX', 'icao': 'ZGSZ', 'terminal': 'T3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:25:00+00:00', 'estimated': '2024-03-08T05:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'SF Airlines', 'iata': 'O3', 'icao': 'CSS'}, 'flight': {'number': '7229', 'iata': 'O37229', 'icao': 'CSS7229', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Quaid-e-azam International', 'timezone': 'Asia/Karachi', 'iata': 'KHI', 'icao': 'OPKC', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T11:00:00+00:00', 'estimated': '2024-03-08T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Queen Alia International', 'timezone': 'Asia/Amman', 'iata': 'AMM', 'icao': 'OJAI', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T13:30:00+00:00', 'estimated': '2024-03-08T13:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Royal Jordanian', 'iata': 'RJ', 'icao': 'RJA'}, 'flight': {'number': '92', 'iata': 'RJ92', 'icao': 'RJA92', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Malé International Airport', 'timezone': 'Indian/Maldives', 'iata': 'MLE', 'icao': 'VRMM', 'terminal': 'MAIN', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T10:55:00+00:00', 'estimated': '2024-03-08T10:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Dubai', 'timezone': 'Asia/Dubai', 'iata': 'DXB', 'icao': 'OMDB', 'terminal': '3', 'gate': None, 'baggage': '11', 'delay': None, 'scheduled': '2024-03-08T14:05:00+00:00', 'estimated': '2024-03-08T14:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}, 'flight': {'number': '659', 'iata': 'EK659', 'icao': 'UAE659', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Wellington International', 'timezone': 'Pacific/Auckland', 'iata': 'WLG', 'icao': 'NZWN', 'terminal': None, 'gate': '17', 'delay': 65, 'scheduled': '2024-03-08T06:35:00+00:00', 'estimated': '2024-03-08T06:35:00+00:00', 'actual': '2024-03-08T07:39:00+00:00', 'estimated_runway': '2024-03-08T07:39:00+00:00', 'actual_runway': '2024-03-08T07:39:00+00:00'}, 'arrival': {'airport': 'Christchurch International', 'timezone': 'Pacific/Auckland', 'iata': 'CHC', 'icao': 'NZCH', 'terminal': 'D', 'gate': 'D16', 'baggage': None, 'delay': 45, 'scheduled': '2024-03-08T07:30:00+00:00', 'estimated': '2024-03-08T07:30:00+00:00', 'actual': '2024-03-08T08:15:00+00:00', 'estimated_runway': '2024-03-08T08:15:00+00:00', 'actual_runway': '2024-03-08T08:15:00+00:00'}, 'airline': {'name': 'Air New Zealand', 'iata': 'NZ', 'icao': 'ANZ'}, 'flight': {'number': '331', 'iata': 'NZ331', 'icao': 'ANZ331', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Dubai', 'timezone': 'Asia/Dubai', 'iata': 'DXB', 'icao': 'OMDB', 'terminal': '3', 'gate': 'A16', 'delay': 31, 'scheduled': '2024-03-08T01:25:00+00:00', 'estimated': '2024-03-08T01:25:00+00:00', 'actual': '2024-03-08T01:55:00+00:00', 'estimated_runway': '2024-03-08T01:55:00+00:00', 'actual_runway': '2024-03-08T01:55:00+00:00'}, 'arrival': {'airport': 'Kuwait International', 'timezone': 'Asia/Kuwait', 'iata': 'KWI', 'icao': 'OKKK', 'terminal': '1', 'gate': '26', 'baggage': None, 'delay': 2, 'scheduled': '2024-03-08T02:15:00+00:00', 'estimated': '2024-03-08T02:15:00+00:00', 'actual': '2024-03-08T02:17:00+00:00', 'estimated_runway': '2024-03-08T02:17:00+00:00', 'actual_runway': '2024-03-08T02:17:00+00:00'}, 'airline': {'name': 'United Airlines', 'iata': 'UA', 'icao': 'UAL'}, 'flight': {'number': '6574', 'iata': 'UA6574', 'icao': 'UAL6574', 'codeshared': {'airline_name': 'emirates', 'airline_iata': 'ek', 'airline_icao': 'uae', 'flight_number': '853', 'flight_iata': 'ek853', 'flight_icao': 'uae853'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shenyang', 'timezone': 'Asia/Shanghai', 'iata': 'SHE', 'icao': 'ZYTX', 'terminal': None, 'gate': None, 'delay': 10, 'scheduled': '2024-03-08T08:20:00+00:00', 'estimated': '2024-03-08T08:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shenzhen', 'timezone': 'Asia/Shanghai', 'iata': 'SZX', 'icao': 'ZGSZ', 'terminal': 'T3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:20:00+00:00', 'estimated': '2024-03-08T12:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'}, 'flight': {'number': '6311', 'iata': 'CZ6311', 'icao': 'CSN6311', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Fenghuang International (Phoenix International)', 'timezone': 'Asia/Shanghai', 'iata': 'SYX', 'icao': 'ZJSY', 'terminal': None, 'gate': 'G', 'delay': 19, 'scheduled': '2024-03-08T04:50:00+00:00', 'estimated': '2024-03-08T04:50:00+00:00', 'actual': '2024-03-08T05:09:00+00:00', 'estimated_runway': '2024-03-08T05:09:00+00:00', 'actual_runway': '2024-03-08T05:09:00+00:00'}, 'arrival': {'airport': 'Sheremetyevo International', 'timezone': 'Europe/Moscow', 'iata': 'SVO', 'icao': 'UUEE', 'terminal': 'C', 'gate': '137', 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:50:00+00:00', 'estimated': '2024-03-08T10:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Aeroflot', 'iata': 'SU', 'icao': 'AFL'}, 'flight': {'number': '225', 'iata': 'SU225', 'icao': 'AFL225', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Jiamusi', 'timezone': 'Asia/Shanghai', 'iata': 'JMU', 'icao': 'ZYJM', 'terminal': None, 'gate': '2', 'delay': None, 'scheduled': '2024-03-08T13:45:00+00:00', 'estimated': '2024-03-08T13:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Yantai', 'timezone': 'Asia/Shanghai', 'iata': 'YNT', 'icao': 'ZSYT', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T16:15:00+00:00', 'estimated': '2024-03-08T16:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Shenzhen Airlines', 'iata': 'ZH', 'icao': 'CSZ'}, 'flight': {'number': '2795', 'iata': 'ZH2795', 'icao': 'CSZ2795', 'codeshared': {'airline_name': 'shandong airlines', 'airline_iata': 'sc', 'airline_icao': 'cdg', 'flight_number': '7633', 'flight_iata': 'sc7633', 'flight_icao': 'cdg7633'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Yantai', 'timezone': 'Asia/Shanghai', 'iata': 'YNT', 'icao': 'ZSYT', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T04:00:00+00:00', 'estimated': '2024-03-08T04:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Zhengzhou', 'timezone': 'Asia/Shanghai', 'iata': 'CGO', 'icao': 'ZHCC', 'terminal': 'T2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:35:00+00:00', 'estimated': '2024-03-08T05:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Longhao Airlines', 'iata': 'GI', 'icao': 'LHA'}, 'flight': {'number': '4110', 'iata': 'GI4110', 'icao': 'LHA4110', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Yantai', 'timezone': 'Asia/Shanghai', 'iata': 'YNT', 'icao': 'ZSYT', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T08:30:00+00:00', 'estimated': '2024-03-08T08:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T11:00:00+00:00', 'estimated': '2024-03-08T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Longhao Airlines', 'iata': 'GI', 'icao': 'LHA'}, 'flight': {'number': '4217', 'iata': 'GI4217', 'icao': 'LHA4217', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hangzhou', 'timezone': 'Asia/Shanghai', 'iata': 'HGH', 'icao': 'ZSHC', 'terminal': '3', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T13:00:00+00:00', 'estimated': '2024-03-08T13:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shuangliu', 'timezone': 'Asia/Shanghai', 'iata': 'CTU', 'icao': 'ZUUU', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T16:10:00+00:00', 'estimated': '2024-03-08T16:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'}, 'flight': {'number': '6172', 'iata': 'MU6172', 'icao': 'CES6172', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Baghdad International', 'timezone': 'Asia/Baghdad', 'iata': 'BGW', 'icao': 'ORBI', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T07:30:00+00:00', 'estimated': '2024-03-08T07:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Erbil International (irbil Northwest)', 'timezone': 'Asia/Baghdad', 'iata': 'EBL', 'icao': 'ORER', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T08:30:00+00:00', 'estimated': '2024-03-08T08:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Fly Baghdad', 'iata': 'IF', 'icao': 'FBA'}, 'flight': {'number': '701', 'iata': 'IF701', 'icao': 'FBA701', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Peretola', 'timezone': 'Europe/Rome', 'iata': 'FLR', 'icao': 'LIRQ', 'terminal': None, 'gate': '1', 'delay': 10, 'scheduled': '2024-03-08T06:35:00+00:00', 'estimated': '2024-03-08T06:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Leonardo Da Vinci (Fiumicino)', 'timezone': 'Europe/Rome', 'iata': 'FCO', 'icao': 'LIRF', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:25:00+00:00', 'estimated': '2024-03-08T07:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air Serbia', 'iata': 'JU', 'icao': 'ASL'}, 'flight': {'number': '7335', 'iata': 'JU7335', 'icao': 'ASL7335', 'codeshared': {'airline_name': 'ita airways', 'airline_iata': 'az', 'airline_icao': 'ity', 'flight_number': '1676', 'flight_iata': 'az1676', 'flight_icao': 'ity1676'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Civil', 'timezone': 'Asia/Kolkata', 'iata': 'TRZ', 'icao': 'VOTR', 'terminal': None, 'gate': None, 'delay': 48, 'scheduled': '2024-03-08T01:15:00+00:00', 'estimated': '2024-03-08T01:15:00+00:00', 'actual': '2024-03-08T02:02:00+00:00', 'estimated_runway': '2024-03-08T02:02:00+00:00', 'actual_runway': '2024-03-08T02:02:00+00:00'}, 'arrival': {'airport': 'Dubai', 'timezone': 'Asia/Dubai', 'iata': 'DXB', 'icao': 'OMDB', 'terminal': '2', 'gate': None, 'baggage': '6', 'delay': 21, 'scheduled': '2024-03-08T04:30:00+00:00', 'estimated': '2024-03-08T04:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air India Express', 'iata': 'IX', 'icao': 'AXB'}, 'flight': {'number': '611', 'iata': 'IX611', 'icao': 'AXB611', 'codeshared': None}, 'aircraft': {'registration': 'VT-AXM', 'iata': 'B738', 'icao': 'B738', 'icao24': '8003B1'}, 'live': {'updated': '2024-03-07T21:50:42+00:00', 'latitude': 14.86, 'longitude': 70.3997, 'altitude': 10363.2, 'direction': 302, 'speed_horizontal': 825.992, 'speed_vertical': 0, 'is_ground': False}}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Civil', 'timezone': 'Asia/Kolkata', 'iata': 'TRZ', 'icao': 'VOTR', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:35:00+00:00', 'estimated': '2024-03-08T01:35:00+00:00', 'actual': '2024-03-08T01:25:00+00:00', 'estimated_runway': '2024-03-08T01:25:00+00:00', 'actual_runway': '2024-03-08T01:25:00+00:00'}, 'arrival': {'airport': 'Singapore Changi', 'timezone': 'Asia/Singapore', 'iata': 'SIN', 'icao': 'WSSS', 'terminal': '1', 'gate': None, 'baggage': '10', 'delay': None, 'scheduled': '2024-03-08T08:15:00+00:00', 'estimated': '2024-03-08T08:15:00+00:00', 'actual': '2024-03-08T07:54:00+00:00', 'estimated_runway': '2024-03-08T07:54:00+00:00', 'actual_runway': '2024-03-08T07:54:00+00:00'}, 'airline': {'name': 'Singapore Airlines', 'iata': 'SQ', 'icao': 'SIA'}, 'flight': {'number': '8369', 'iata': 'SQ8369', 'icao': 'SIA8369', 'codeshared': {'airline_name': 'scoot', 'airline_iata': 'tr', 'airline_icao': 'tgw', 'flight_number': '567', 'flight_iata': 'tr567', 'flight_icao': 'tgw567'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Civil', 'timezone': 'Asia/Kolkata', 'iata': 'TRZ', 'icao': 'VOTR', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T01:35:00+00:00', 'estimated': '2024-03-08T01:35:00+00:00', 'actual': '2024-03-08T01:25:00+00:00', 'estimated_runway': '2024-03-08T01:25:00+00:00', 'actual_runway': '2024-03-08T01:25:00+00:00'}, 'arrival': {'airport': 'Singapore Changi', 'timezone': 'Asia/Singapore', 'iata': 'SIN', 'icao': 'WSSS', 'terminal': '1', 'gate': None, 'baggage': '10', 'delay': None, 'scheduled': '2024-03-08T08:15:00+00:00', 'estimated': '2024-03-08T08:15:00+00:00', 'actual': '2024-03-08T07:54:00+00:00', 'estimated_runway': '2024-03-08T07:54:00+00:00', 'actual_runway': '2024-03-08T07:54:00+00:00'}, 'airline': {'name': 'Scoot', 'iata': 'TR', 'icao': 'TGW'}, 'flight': {'number': '567', 'iata': 'TR567', 'icao': 'TGW567', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Guangzhou Baiyun International', 'timezone': 'Asia/Shanghai', 'iata': 'CAN', 'icao': 'ZGGG', 'terminal': '1', 'gate': 'D', 'delay': 16, 'scheduled': '2024-03-08T08:05:00+00:00', 'estimated': '2024-03-08T08:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Beijing Capital International', 'timezone': 'Asia/Shanghai', 'iata': 'PEK', 'icao': 'ZBAA', 'terminal': '3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T11:00:00+00:00', 'estimated': '2024-03-08T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Shenzhen Airlines', 'iata': 'ZH', 'icao': 'CSZ'}, 'flight': {'number': '1310', 'iata': 'ZH1310', 'icao': 'CSZ1310', 'codeshared': {'airline_name': 'air china ltd', 'airline_iata': 'ca', 'airline_icao': 'cca', 'flight_number': '1310', 'flight_iata': 'ca1310', 'flight_icao': 'cca1310'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Taizhou', 'timezone': 'Asia/Shanghai', 'iata': 'YTY', 'icao': 'ZSYA', 'terminal': None, 'gate': '2-5', 'delay': None, 'scheduled': '2024-03-08T10:50:00+00:00', 'estimated': '2024-03-08T10:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Beijing Capital International', 'timezone': 'Asia/Shanghai', 'iata': 'PEK', 'icao': 'ZBAA', 'terminal': '3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:45:00+00:00', 'estimated': '2024-03-08T12:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Shenzhen Airlines', 'iata': 'ZH', 'icao': 'CSZ'}, 'flight': {'number': '1842', 'iata': 'ZH1842', 'icao': 'CSZ1842', 'codeshared': {'airline_name': 'air china ltd', 'airline_iata': 'ca', 'airline_icao': 'cca', 'flight_number': '1842', 'flight_iata': 'ca1842', 'flight_icao': 'cca1842'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Beauvais-Tille', 'timezone': 'Europe/Paris', 'iata': 'BVA', 'icao': 'LFOB', 'terminal': None, 'gate': None, 'delay': 15, 'scheduled': '2024-03-08T06:05:00+00:00', 'estimated': '2024-03-08T06:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Alicante El Altet', 'timezone': 'Europe/Madrid', 'iata': 'ALC', 'icao': 'LEAL', 'terminal': None, 'gate': None, 'baggage': '10B', 'delay': None, 'scheduled': '2024-03-08T08:15:00+00:00', 'estimated': '2024-03-08T08:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}, 'flight': {'number': '9035', 'iata': 'FR9035', 'icao': 'RYR9035', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Haneda Airport', 'timezone': 'Asia/Tokyo', 'iata': 'HND', 'icao': 'RJTT', 'terminal': '3', 'gate': '145', 'delay': 22, 'scheduled': '2024-03-08T01:40:00+00:00', 'estimated': '2024-03-08T01:40:00+00:00', 'actual': '2024-03-08T02:01:00+00:00', 'estimated_runway': '2024-03-08T02:01:00+00:00', 'actual_runway': '2024-03-08T02:01:00+00:00'}, 'arrival': {'airport': 'Hong Kong International', 'timezone': 'Asia/Hong_Kong', 'iata': 'HKG', 'icao': 'VHHH', 'terminal': '1', 'gate': None, 'baggage': '16', 'delay': None, 'scheduled': '2024-03-08T05:55:00+00:00', 'estimated': '2024-03-08T05:55:00+00:00', 'actual': '2024-03-08T05:47:00+00:00', 'estimated_runway': '2024-03-08T05:47:00+00:00', 'actual_runway': '2024-03-08T05:47:00+00:00'}, 'airline': {'name': 'Cathay Pacific', 'iata': 'CX', 'icao': 'CPA'}, 'flight': {'number': '5629', 'iata': 'CX5629', 'icao': 'CPA5629', 'codeshared': {'airline_name': 'hong kong express', 'airline_iata': 'uo', 'airline_icao': 'hke', 'flight_number': '629', 'flight_iata': 'uo629', 'flight_icao': 'hke629'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Nanjing Lukou International Airport', 'timezone': 'Asia/Shanghai', 'iata': 'NKG', 'icao': 'ZSNJ', 'terminal': '1', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T13:45:00+00:00', 'estimated': '2024-03-08T13:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Harbin', 'timezone': 'Asia/Shanghai', 'iata': 'HRB', 'icao': 'ZYHB', 'terminal': 'T2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T16:40:00+00:00', 'estimated': '2024-03-08T16:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': '9 Air Co', 'iata': 'AQ', 'icao': 'JYH'}, 'flight': {'number': '1501', 'iata': 'AQ1501', 'icao': 'JYH1501', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Karaganda', 'timezone': 'Asia/Almaty', 'iata': 'KGF', 'icao': 'UAKK', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T06:00:00+00:00', 'estimated': '2024-03-08T06:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Almaty', 'timezone': 'Asia/Almaty', 'iata': 'ALA', 'icao': 'UAAA', 'terminal': 'I', 'gate': None, 'baggage': '6', 'delay': None, 'scheduled': '2024-03-08T07:35:00+00:00', 'estimated': '2024-03-08T07:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air Astana', 'iata': 'KC', 'icao': 'KZR'}, 'flight': {'number': '7122', 'iata': 'KC7122', 'icao': 'KZR7122', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Ninoy Aquino International', 'timezone': 'Asia/Manila', 'iata': 'MNL', 'icao': 'RPLL', 'terminal': '2', 'gate': None, 'delay': 15, 'scheduled': '2024-03-08T04:20:00+00:00', 'estimated': '2024-03-08T04:20:00+00:00', 'actual': '2024-03-08T04:34:00+00:00', 'estimated_runway': '2024-03-08T04:34:00+00:00', 'actual_runway': '2024-03-08T04:34:00+00:00'}, 'arrival': {'airport': 'Mactan-Cebu International', 'timezone': 'Asia/Manila', 'iata': 'CEB', 'icao': 'RPVM', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T05:50:00+00:00', 'estimated': '2024-03-08T05:50:00+00:00', 'actual': '2024-03-08T05:46:00+00:00', 'estimated_runway': '2024-03-08T05:46:00+00:00', 'actual_runway': '2024-03-08T05:46:00+00:00'}, 'airline': {'name': 'Philippine Airlines', 'iata': 'PR', 'icao': 'PAL'}, 'flight': {'number': '2835', 'iata': 'PR2835', 'icao': 'PAL2835', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Naha', 'timezone': 'Asia/Tokyo', 'iata': 'OKA', 'icao': 'ROAH', 'terminal': 'D', 'gate': '97', 'delay': None, 'scheduled': '2024-03-08T14:40:00+00:00', 'estimated': '2024-03-08T14:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Ishigaki', 'timezone': 'Asia/Tokyo', 'iata': 'ISG', 'icao': 'ROIG', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T15:45:00+00:00', 'estimated': '2024-03-08T15:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Asiana Airlines', 'iata': 'OZ', 'icao': 'AAR'}, 'flight': {'number': '9173', 'iata': 'OZ9173', 'icao': 'AAR9173', 'codeshared': {'airline_name': 'ana', 'airline_iata': 'nh', 'airline_icao': 'ana', 'flight_number': '1771', 'flight_iata': 'nh1771', 'flight_icao': 'ana1771'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'DRV', 'icao': 'VRMD', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T07:05:00+00:00', 'estimated': '2024-03-08T07:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Malé International Airport', 'timezone': 'Indian/Maldives', 'iata': 'MLE', 'icao': 'VRMM', 'terminal': 'MAIN', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:40:00+00:00', 'estimated': '2024-03-08T07:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Minoan Air', 'iata': 'NR', 'icao': 'MAV'}, 'flight': {'number': '521', 'iata': 'NR521', 'icao': 'MAV521', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Zurich', 'timezone': 'Europe/Zurich', 'iata': 'ZRH', 'icao': 'LSZH', 'terminal': None, 'gate': '1', 'delay': None, 'scheduled': '2024-03-08T06:55:00+00:00', 'estimated': '2024-03-08T06:55:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Capodichino', 'timezone': 'Europe/Rome', 'iata': 'NAP', 'icao': 'LIRN', 'terminal': None, 'gate': 'SCH', 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T08:35:00+00:00', 'estimated': '2024-03-08T08:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air Baltic', 'iata': 'BT', 'icao': 'BTI'}, 'flight': {'number': '1710', 'iata': 'BT1710', 'icao': 'BTI1710', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '1', 'gate': '12', 'delay': None, 'scheduled': '2024-03-08T08:30:00+00:00', 'estimated': '2024-03-08T08:30:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Harbin', 'timezone': 'Asia/Shanghai', 'iata': 'HRB', 'icao': 'ZYHB', 'terminal': 'T2', 'gate': None, 'baggage': '8', 'delay': None, 'scheduled': '2024-03-08T11:20:00+00:00', 'estimated': '2024-03-08T11:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Qantas', 'iata': 'QF', 'icao': 'QFA'}, 'flight': {'number': '4028', 'iata': 'QF4028', 'icao': 'QFA4028', 'codeshared': {'airline_name': 'china eastern airlines', 'airline_iata': 'mu', 'airline_icao': 'ces', 'flight_number': '5613', 'flight_iata': 'mu5613', 'flight_icao': 'ces5613'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Changsha', 'timezone': 'Asia/Shanghai', 'iata': 'CSX', 'icao': 'ZGHA', 'terminal': '2', 'gate': 'B,C', 'delay': None, 'scheduled': '2024-03-08T12:15:00+00:00', 'estimated': '2024-03-08T12:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Yun Cheng', 'timezone': 'Asia/Shanghai', 'iata': 'YCU', 'icao': 'ZBYC', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T14:05:00+00:00', 'estimated': '2024-03-08T14:05:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Sichuan Airlines', 'iata': '3U', 'icao': 'CSC'}, 'flight': {'number': '2203', 'iata': '3U2203', 'icao': 'CSC2203', 'codeshared': {'airline_name': 'xiamen airlines', 'airline_iata': 'mf', 'airline_icao': 'cxa', 'flight_number': '8245', 'flight_iata': 'mf8245', 'flight_icao': 'cxa8245'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'active', 'departure': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': None, 'gate': None, 'delay': 27, 'scheduled': '2024-03-08T01:55:00+00:00', 'estimated': '2024-03-08T01:55:00+00:00', 'actual': '2024-03-08T02:21:00+00:00', 'estimated_runway': '2024-03-08T02:21:00+00:00', 'actual_runway': '2024-03-08T02:21:00+00:00'}, 'arrival': {'airport': 'Ted Stevens Anchorage International Airport', 'timezone': 'America/Anchorage', 'iata': 'ANC', 'icao': 'PANC', 'terminal': 'S', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-07T15:22:00+00:00', 'estimated': '2024-03-07T15:22:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Atlas Air', 'iata': '5Y', 'icao': 'GTI'}, 'flight': {'number': '654', 'iata': '5Y654', 'icao': 'GTI654', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Phuket International', 'timezone': 'Asia/Bangkok', 'iata': 'HKT', 'icao': 'VTSP', 'terminal': 'D', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T12:45:00+00:00', 'estimated': '2024-03-08T12:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Suvarnabhumi International', 'timezone': 'Asia/Bangkok', 'iata': 'BKK', 'icao': 'VTBS', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T14:15:00+00:00', 'estimated': '2024-03-08T14:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Emirates', 'iata': 'EK', 'icao': 'UAE'}, 'flight': {'number': '4523', 'iata': 'EK4523', 'icao': 'UAE4523', 'codeshared': {'airline_name': 'bangkok airways', 'airline_iata': 'pg', 'airline_icao': 'bkp', 'flight_number': '276', 'flight_iata': 'pg276', 'flight_icao': 'bkp276'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'HUZ', 'icao': 'ZGHZ', 'terminal': None, 'gate': '5-12', 'delay': None, 'scheduled': '2024-03-08T11:00:00+00:00', 'estimated': '2024-03-08T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Hangzhou', 'timezone': 'Asia/Shanghai', 'iata': 'HGH', 'icao': 'ZSHC', 'terminal': '3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:50:00+00:00', 'estimated': '2024-03-08T12:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Southern Airlines', 'iata': 'CZ', 'icao': 'CSN'}, 'flight': {'number': '28', 'iata': 'CZ28', 'icao': 'CSN28', 'codeshared': {'airline_name': 'juneyao airlines', 'airline_iata': 'ho', 'airline_icao': 'dkh', 'flight_number': '2034', 'flight_iata': 'ho2034', 'flight_icao': 'dkh2034'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'HUZ', 'icao': 'ZGHZ', 'terminal': None, 'gate': '5-12', 'delay': None, 'scheduled': '2024-03-08T11:00:00+00:00', 'estimated': '2024-03-08T11:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Hangzhou', 'timezone': 'Asia/Shanghai', 'iata': 'HGH', 'icao': 'ZSHC', 'terminal': '3', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:50:00+00:00', 'estimated': '2024-03-08T12:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Shenzhen Airlines', 'iata': 'ZH', 'icao': 'CSZ'}, 'flight': {'number': '5250', 'iata': 'ZH5250', 'icao': 'CSZ5250', 'codeshared': {'airline_name': 'juneyao airlines', 'airline_iata': 'ho', 'airline_icao': 'dkh', 'flight_number': '2034', 'flight_iata': 'ho2034', 'flight_icao': 'dkh2034'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': None, 'timezone': None, 'iata': 'HUZ', 'icao': 'ZGHZ', 'terminal': None, 'gate': '5-12', 'delay': None, 'scheduled': '2024-03-08T10:50:00+00:00', 'estimated': '2024-03-08T10:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '2', 'gate': None, 'baggage': '35', 'delay': None, 'scheduled': '2024-03-08T13:00:00+00:00', 'estimated': '2024-03-08T13:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air China LTD', 'iata': 'CA', 'icao': 'CCA'}, 'flight': {'number': '8578', 'iata': 'CA8578', 'icao': 'CCA8578', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Matei', 'timezone': 'Pacific/Fiji', 'iata': 'TVU', 'icao': 'NFNM', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T14:15:00+00:00', 'estimated': '2024-03-08T14:15:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Nadi International', 'timezone': 'Pacific/Fiji', 'iata': 'NAN', 'icao': 'NFFN', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T15:40:00+00:00', 'estimated': '2024-03-08T15:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Fiji Airways', 'iata': 'FJ', 'icao': 'FJI'}, 'flight': {'number': '126', 'iata': 'FJ126', 'icao': 'FJI126', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Matsumoto', 'timezone': 'Asia/Tokyo', 'iata': 'MMJ', 'icao': 'RJAF', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T10:35:00+00:00', 'estimated': '2024-03-08T10:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kobe', 'timezone': 'Asia/Tokyo', 'iata': 'UKB', 'icao': 'RJBE', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T11:40:00+00:00', 'estimated': '2024-03-08T11:40:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Jet Linx Aviation', 'iata': 'JL', 'icao': 'JTL'}, 'flight': {'number': '2602', 'iata': 'JL2602', 'icao': 'JTL2602', 'codeshared': {'airline_name': 'fuji dream airlines', 'airline_iata': 'jh', 'airline_icao': 'fda', 'flight_number': '233', 'flight_iata': 'jh233', 'flight_icao': 'fda233'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Kobe', 'timezone': 'Asia/Tokyo', 'iata': 'UKB', 'icao': 'RJBE', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T11:10:00+00:00', 'estimated': '2024-03-08T11:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Haneda Airport', 'timezone': 'Asia/Tokyo', 'iata': 'HND', 'icao': 'RJTT', 'terminal': '1', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:20:00+00:00', 'estimated': '2024-03-08T12:20:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Skymark Airlines', 'iata': 'BC', 'icao': 'SKY'}, 'flight': {'number': '106', 'iata': 'BC106', 'icao': 'SKY106', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Noibai International', 'timezone': 'Asia/Ho_Chi_Minh', 'iata': 'HAN', 'icao': 'VVNB', 'terminal': 'T2', 'gate': None, 'delay': None, 'scheduled': '2024-03-08T09:25:00+00:00', 'estimated': '2024-03-08T09:25:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Wattay', 'timezone': 'Asia/Vientiane', 'iata': 'VTE', 'icao': 'VLVT', 'terminal': 'D', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:45:00+00:00', 'estimated': '2024-03-08T10:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Cambodia Angkor Air', 'iata': 'K6', 'icao': 'KHV'}, 'flight': {'number': '3921', 'iata': 'K63921', 'icao': 'KHV3921', 'codeshared': {'airline_name': 'vietnam airlines', 'airline_iata': 'vn', 'airline_icao': 'hvn', 'flight_number': '921', 'flight_iata': 'vn921', 'flight_icao': 'hvn921'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Istanbul Airport', 'timezone': 'Europe/Istanbul', 'iata': 'IST', 'icao': 'LTFM', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T08:35:00+00:00', 'estimated': '2024-03-08T08:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kastrup', 'timezone': 'Europe/Copenhagen', 'iata': 'CPH', 'icao': 'EKCH', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:00:00+00:00', 'estimated': '2024-03-08T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Pakistan International Airlines', 'iata': 'PK', 'icao': 'PIA'}, 'flight': {'number': '5783', 'iata': 'PK5783', 'icao': 'PIA5783', 'codeshared': {'airline_name': 'turkish airlines', 'airline_iata': 'tk', 'airline_icao': 'thy', 'flight_number': '1783', 'flight_iata': 'tk1783', 'flight_icao': 'thy1783'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Istanbul Airport', 'timezone': 'Europe/Istanbul', 'iata': 'IST', 'icao': 'LTFM', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T08:35:00+00:00', 'estimated': '2024-03-08T08:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kastrup', 'timezone': 'Europe/Copenhagen', 'iata': 'CPH', 'icao': 'EKCH', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:00:00+00:00', 'estimated': '2024-03-08T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Gulf Air', 'iata': 'GF', 'icao': 'GFA'}, 'flight': {'number': '6055', 'iata': 'GF6055', 'icao': 'GFA6055', 'codeshared': {'airline_name': 'turkish airlines', 'airline_iata': 'tk', 'airline_icao': 'thy', 'flight_number': '1783', 'flight_iata': 'tk1783', 'flight_icao': 'thy1783'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Istanbul Airport', 'timezone': 'Europe/Istanbul', 'iata': 'IST', 'icao': 'LTFM', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T08:35:00+00:00', 'estimated': '2024-03-08T08:35:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kastrup', 'timezone': 'Europe/Copenhagen', 'iata': 'CPH', 'icao': 'EKCH', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T10:00:00+00:00', 'estimated': '2024-03-08T10:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air Canada', 'iata': 'AC', 'icao': 'ACA'}, 'flight': {'number': '6693', 'iata': 'AC6693', 'icao': 'ACA6693', 'codeshared': {'airline_name': 'turkish airlines', 'airline_iata': 'tk', 'airline_icao': 'thy', 'flight_number': '1783', 'flight_iata': 'tk1783', 'flight_icao': 'thy1783'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hohhot', 'timezone': 'Asia/Shanghai', 'iata': 'HET', 'icao': 'ZBHH', 'terminal': None, 'gate': 'C', 'delay': None, 'scheduled': '2024-03-08T11:50:00+00:00', 'estimated': '2024-03-08T11:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Saiwusu International', 'timezone': 'Asia/Shanghai', 'iata': 'ERL', 'icao': 'ZBER', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:45:00+00:00', 'estimated': '2024-03-08T12:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Xiamen Airlines', 'iata': 'MF', 'icao': 'CXA'}, 'flight': {'number': '2595', 'iata': 'MF2595', 'icao': 'CXA2595', 'codeshared': {'airline_name': 'china express air', 'airline_iata': 'g5', 'airline_icao': 'hxa', 'flight_number': '4219', 'flight_iata': 'g54219', 'flight_icao': 'hxa4219'}}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hohhot', 'timezone': 'Asia/Shanghai', 'iata': 'HET', 'icao': 'ZBHH', 'terminal': None, 'gate': 'D', 'delay': 62, 'scheduled': '2024-03-08T11:50:00+00:00', 'estimated': '2024-03-08T11:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Kunming', 'timezone': 'Asia/Shanghai', 'iata': 'KMG', 'icao': 'ZPPP', 'terminal': None, 'gate': None, 'baggage': '6', 'delay': None, 'scheduled': '2024-03-08T15:10:00+00:00', 'estimated': '2024-03-08T15:10:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Eastern Airlines', 'iata': 'MU', 'icao': 'CES'}, 'flight': {'number': '6927', 'iata': 'MU6927', 'icao': 'CES6927', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'scheduled', 'departure': {'airport': 'Hohhot', 'timezone': 'Asia/Shanghai', 'iata': 'HET', 'icao': 'ZBHH', 'terminal': None, 'gate': 'C', 'delay': None, 'scheduled': '2024-03-08T11:50:00+00:00', 'estimated': '2024-03-08T11:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Saiwusu International', 'timezone': 'Asia/Shanghai', 'iata': 'ERL', 'icao': 'ZBER', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T12:45:00+00:00', 'estimated': '2024-03-08T12:45:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'China Express Air', 'iata': 'G5', 'icao': 'HXA'}, 'flight': {'number': '4219', 'iata': 'G54219', 'icao': 'HXA4219', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'landed', 'departure': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': '1', 'gate': None, 'delay': 56, 'scheduled': '2024-03-08T03:05:00+00:00', 'estimated': '2024-03-08T03:05:00+00:00', 'actual': '2024-03-08T04:01:00+00:00', 'estimated_runway': '2024-03-08T04:01:00+00:00', 'actual_runway': '2024-03-08T04:01:00+00:00'}, 'arrival': {'airport': 'Seoul (Incheon)', 'timezone': 'Asia/Seoul', 'iata': 'ICN', 'icao': 'RKSI', 'terminal': '2', 'gate': None, 'baggage': None, 'delay': 21, 'scheduled': '2024-03-08T06:05:00+00:00', 'estimated': '2024-03-08T06:05:00+00:00', 'actual': '2024-03-08T06:25:00+00:00', 'estimated_runway': '2024-03-08T06:25:00+00:00', 'actual_runway': '2024-03-08T06:25:00+00:00'}, 'airline': {'name': 'Korean Air', 'iata': 'KE', 'icao': 'KAL'}, 'flight': {'number': '316', 'iata': 'KE316', 'icao': 'KAL316', 'codeshared': None}, 'aircraft': None, 'live': None}, {'flight_date': '2024-03-08', 'flight_status': 'unknown', 'departure': {'airport': 'Shanghai Pudong International', 'timezone': 'Asia/Shanghai', 'iata': 'PVG', 'icao': 'ZSPD', 'terminal': None, 'gate': None, 'delay': None, 'scheduled': '2024-03-08T03:00:00+00:00', 'estimated': '2024-03-08T03:00:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'arrival': {'airport': 'Frankfurt International Airport', 'timezone': 'Europe/Berlin', 'iata': 'FRA', 'icao': 'EDDF', 'terminal': None, 'gate': None, 'baggage': None, 'delay': None, 'scheduled': '2024-03-08T07:50:00+00:00', 'estimated': '2024-03-08T07:50:00+00:00', 'actual': None, 'estimated_runway': None, 'actual_runway': None}, 'airline': {'name': 'Air China LTD', 'iata': 'CA', 'icao': 'CCA'}, 'flight': {'number': '1047', 'iata': 'CA1047', 'icao': 'CCA1047', 'codeshared': None}, 'aircraft': None, 'live': None}]}

# %%
# Out:
# Error: API request failed with status code 401

# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
from datetime import datetime

# Load environment variables from .env file
load_dotenv()

api_key = os.getenv('AVIATIONSTACK_API_KEY')  # Getting API key from environment variable

def extract_flights(date_param):
    all_data = []
    limit = 100  # Set the limit for each request
    offset = 0

    while True:
        params = {'access_key': api_key, 'flight_date': date_param, 'limit': limit, 'offset': offset}
        api_result = requests.get('http://api.aviationstack.com/v1/flights', params)
        
        # Check for errors in the API request
        if api_result.status_code != 200:
            print(f"Error: API request failed with status code {api_result.status_code}")
            return None
        
        data = api_result.json()

        # Check if the 'data' key exists in the response
        if 'data' not in data:
            print("Error: 'data' key not found in API response.")
            return None

        # Check if there are no more results left
        if not data["data"]:
            break

        for flight_data in data["data"]:
            # Extract all flight data fields
            all_data.append({
                "flight_date": flight_data["flight_date"],
                "flight_status": flight_data["flight_status"],
                "departure_airport": flight_data["departure"]["airport"],
                "departure_timezone": flight_data["departure"]["timezone"],
                "departure_iata": flight_data["departure"]["iata"],
                "departure_icao": flight_data["departure"]["icao"],
                "departure_terminal": flight_data["departure"]["terminal"],
                "departure_gate": flight_data["departure"]["gate"],
                "departure_delay": flight_data["departure"]["delay"],
                "departure_scheduled": flight_data["departure"]["scheduled"],
                "departure_estimated": flight_data["departure"]["estimated"],
                "departure_actual": flight_data["departure"]["actual"],
                "departure_estimated_runway": flight_data["departure"]["estimated_runway"],
                "departure_actual_runway": flight_data["departure"]["actual_runway"],
                "arrival_airport": flight_data["arrival"]["airport"],
                "arrival_timezone": flight_data["arrival"]["timezone"],
                "arrival_iata": flight_data["arrival"]["iata"],
                "arrival_icao": flight_data["arrival"]["icao"],
                "arrival_terminal": flight_data["arrival"]["terminal"],
                "arrival_gate": flight_data["arrival"]["gate"],
                "arrival_baggage": flight_data["arrival"]["baggage"],
                "arrival_delay": flight_data["arrival"]["delay"],
                "arrival_scheduled": flight_data["arrival"]["scheduled"],
                "arrival_estimated": flight_data["arrival"]["estimated"],
                "arrival_actual": flight_data["arrival"]["actual"],
                "arrival_estimated_runway": flight_data["arrival"]["estimated_runway"],
                "arrival_actual_runway": flight_data["arrival"]["actual_runway"],
                "airline_name": flight_data["airline"]["name"],
                "airline_iata": flight_data["airline"]["iata"],
                "airline_icao": flight_data["airline"]["icao"],
                "flight_number": flight_data["flight"]["number"],
                "flight_iata": flight_data["flight"]["iata"],
                "flight_icao": flight_data["flight"]["icao"],
                "codeshared": flight_data["flight"]["codeshared"],
            })

        offset += limit
        print(f'loaded {offset} data')

    df = pd.DataFrame(all_data)

    # Save the DataFrame as a new CSV file with timestamp
    timestamp = datetime.now().strftime('%Y%m%d%H%M%S')
    csv_file_name = f'flight_{timestamp}.csv'
    df.to_csv(csv_file_name, index=False)
    print(f"CSV file {csv_file_name} saved successfully.")

    return df

# Get today's date
today = datetime.now().strftime('%Y-%m-%d')

# Call the function to extract flights for today
extract_flights(today)
# Out:
# Error: API request failed with status code 403
